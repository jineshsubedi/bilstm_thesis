# %%
# BiLSTM-based Intrusion Detection on TON IoT Dataset (Rewritten)

import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from collections import Counter
from sklearn.model_selection import StratifiedKFold, train_test_split

# Load Dataset
df = pd.read_csv('../dataset/final_df.csv', low_memory=False)
print("Original DataFrame Head:\n", df.head())
print("\nOriginal Class Distribution:\n", df['type'].value_counts())
print("\nOriginal Label Distribution:\n", df['label'].value_counts())
print("\nOriginal Data Types:\n", df.dtypes)
print("\nOriginal Data Shapes:\n", df.shape)

# --- Data Preprocessing ---
# Clean and impute
df['src_bytes'] = pd.to_numeric(df['src_bytes'], errors='coerce').fillna(0)
df.drop_duplicates(inplace=True)

df.fillna(df.mean(numeric_only=True), inplace=True)
print(f"Shape after dropping duplicates: {df.shape}")

for col in df.columns:
    if df[col].isnull().any():
        if df[col].dtype == 'object':
            df[col].fillna('Missing', inplace=True) # Or df[col].mode()[0]
        else:
            df[col].fillna(df[col].mean(), inplace=True)

print(f"Shape after handling NaNs: {df.shape}")

# Identify targets
TARGET_LABEL = 'label'
TARGET_TYPE = 'type'

# Encode categorical columns
categorical_cols = df.select_dtypes(include='object').columns.tolist()
if TARGET_TYPE in categorical_cols:
    categorical_cols.remove(TARGET_TYPE)

label_encoders = {}
for col in categorical_cols:
    le = LabelEncoder()
    df[col] = le.fit_transform(df[col])
    label_encoders[col] = le
    print(f"Encoded column: {col}")

# Normalize numerical features
numerical_cols = df.select_dtypes(include=['int64', 'float64']).columns.tolist()
if TARGET_LABEL in numerical_cols:
    numerical_cols.remove(TARGET_LABEL)

print(f"\nCategorical columns: {categorical_cols}")
print(f"Numerical columns: {numerical_cols}")

binary_y = df[TARGET_LABEL].values
type_encoder = LabelEncoder()
y_multiclass_encoded = type_encoder.fit_transform(df[TARGET_TYPE])
num_classes = len(le.classes_)
# Convert to one-hot encoding for Keras if using categorical_crossentropy
y_multiclass_onehot = to_categorical(y_multiclass_encoded)

y_multiclass_labels = np.argmax(y_multiclass_onehot, axis=1)

# Drop targets from features
X = df.drop(columns=[TARGET_LABEL, TARGET_TYPE]).values
print("Feature shape (flat):", X.shape)
print("Binary target shape:", binary_y.shape)
print("Multi-class target shape:", y_multiclass_labels.shape)

# print the class distribution of binary_y and y_multiclass_labels
print("Binary target class distribution:")
print(Counter(binary_y))
print("Multi-class target class distribution:")
print(Counter(y_multiclass_labels))
# Out:
# 2025-12-13 17:49:13.566932: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-12-13 17:49:13.614895: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-12-13 17:49:14.875834: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# Original DataFrame Head:
#             ts         src_ip  src_port        dst_ip  dst_port proto service  \
# 0  1556499101  192.168.1.193     60396  192.168.1.33      8080   tcp       -
# 1  1556494424  192.168.1.193     59273  192.168.1.33      8080   tcp       -
# 2  1556487945  192.168.1.193     57717  192.168.1.33      8080   tcp       -
# 3  1556508616  192.168.1.193     62682  192.168.1.33        80   tcp       -
# 4  1556511697  192.168.1.193     63419  192.168.1.33      8080   tcp       -
#
#    duration src_bytes  dst_bytes  ... http_response_body_len  \
# 0  0.000180         0          0  ...                      0
# 1  0.000111         0          0  ...                      0
# 2  0.000148         0          0  ...                      0
# 3  0.000127         0          0  ...                      0
# 4  0.000122         0          0  ...                      0
#
#    http_status_code  http_user_agent  http_orig_mime_types  \
# 0                 0                -                     -
# 1                 0                -                     -
# 2                 0                -                     -
# 3                 0                -                     -
# 4                 0                -                     -
#
#    http_resp_mime_types  weird_name weird_addl  weird_notice  label      type
# 0                     -           -          -             -      1  backdoor
# 1                     -           -          -             -      1  backdoor
# 2                     -           -          -             -      1  backdoor
# 3                     -           -          -             -      1  backdoor
# 4                     -           -          -             -      1  backdoor
#
# [5 rows x 46 columns]
#
# Original Class Distribution:
#  type
# normal       300000
# backdoor      20000
# ddos          20000
# injection     20000
# dos           20000
# scanning      20000
# password      20000
# xss           20000
# mitm           1043
# Name: count, dtype: int64
#
# Original Label Distribution:
#  label
# 0    300000
# 1    141043
# Name: count, dtype: int64
#
# Original Data Types:
#  ts                          int64
# src_ip                     object
# src_port                    int64
# dst_ip                     object
# dst_port                    int64
# proto                      object
# service                    object
# duration                  float64
# src_bytes                  object
# dst_bytes                   int64
# conn_state                 object
# missed_bytes                int64
# src_pkts                    int64
# src_ip_bytes                int64
# dst_pkts                    int64
# dst_ip_bytes                int64
# dns_query                  object
# dns_qclass                  int64
# dns_qtype                   int64
# dns_rcode                   int64
# dns_AA                     object
# dns_RD                     object
# dns_RA                     object
# dns_rejected               object
# ssl_version                object
# ssl_cipher                 object
# ssl_resumed                object
# ssl_established            object
# ssl_subject                object
# ssl_issuer                 object
# http_trans_depth           object
# http_method                object
# http_uri                   object
# http_referrer              object
# http_version               object
# http_request_body_len       int64
# http_response_body_len      int64
# http_status_code            int64
# http_user_agent            object
# http_orig_mime_types       object
# http_resp_mime_types       object
# weird_name                 object
# weird_addl                 object
# weird_notice               object
# label                       int64
# type                       object
# dtype: object
#
# Original Data Shapes:
#  (441043, 46)
# Shape after dropping duplicates: (441043, 46)
# Shape after handling NaNs: (441043, 46)
# Encoded column: src_ip
# Encoded column: dst_ip
# Encoded column: proto
# Encoded column: service
# Encoded column: conn_state
# Encoded column: dns_query
# Encoded column: dns_AA
# Encoded column: dns_RD
# Encoded column: dns_RA
# Encoded column: dns_rejected
# Encoded column: ssl_version
# Encoded column: ssl_cipher
# Encoded column: ssl_resumed
# Encoded column: ssl_established
# Encoded column: ssl_subject
# Encoded column: ssl_issuer
# Encoded column: http_trans_depth
# Encoded column: http_method
# Encoded column: http_uri
# Encoded column: http_referrer
# Encoded column: http_version
# Encoded column: http_user_agent
# Encoded column: http_orig_mime_types
# Encoded column: http_resp_mime_types
# Encoded column: weird_name
# Encoded column: weird_addl
# Encoded column: weird_notice
#
# Categorical columns: ['src_ip', 'dst_ip', 'proto', 'service', 'conn_state', 'dns_query', 'dns_AA', 'dns_RD', 'dns_RA', 'dns_rejected', 'ssl_version', 'ssl_cipher', 'ssl_resumed', 'ssl_established', 'ssl_subject', 'ssl_issuer', 'http_trans_depth', 'http_method', 'http_uri', 'http_referrer', 'http_version', 'http_user_agent', 'http_orig_mime_types', 'http_resp_mime_types', 'weird_name', 'weird_addl', 'weird_notice']
# Numerical columns: ['ts', 'src_ip', 'src_port', 'dst_ip', 'dst_port', 'proto', 'service', 'duration', 'src_bytes', 'dst_bytes', 'conn_state', 'missed_bytes', 'src_pkts', 'src_ip_bytes', 'dst_pkts', 'dst_ip_bytes', 'dns_query', 'dns_qclass', 'dns_qtype', 'dns_rcode', 'dns_AA', 'dns_RD', 'dns_RA', 'dns_rejected', 'ssl_version', 'ssl_cipher', 'ssl_resumed', 'ssl_established', 'ssl_subject', 'ssl_issuer', 'http_trans_depth', 'http_method', 'http_uri', 'http_referrer', 'http_version', 'http_request_body_len', 'http_response_body_len', 'http_status_code', 'http_user_agent', 'http_orig_mime_types', 'http_resp_mime_types', 'weird_name', 'weird_addl', 'weird_notice']
# Feature shape (flat): (441043, 44)
# Binary target shape: (441043,)
# Multi-class target shape: (441043,)
# Binary target class distribution:
# Counter({np.int64(0): 300000, np.int64(1): 141043})
# Multi-class target class distribution:
# Counter({np.int64(5): 300000, np.int64(0): 20000, np.int64(1): 20000, np.int64(2): 20000, np.int64(3): 20000, np.int64(6): 20000, np.int64(7): 20000, np.int64(8): 20000, np.int64(4): 1043})

# %%
# 1. Split BEFORE SMOTE (to avoid leakage)
# ----------------------------------------
X_train, X_test, y_train_multi, y_test_multi = train_test_split(
    X,
    y_multiclass_onehot,
    test_size=0.2,
    random_state=42,
    stratify=y_multiclass_encoded  # stratify on binary for this example
)

# Reset indices
X_train = pd.DataFrame(X_train).reset_index(drop=True).values
X_test = pd.DataFrame(X_test).reset_index(drop=True).values

print(f"\nX_train shape: {X_train.shape}")
print(f"y_train_multiclass labels shape: {y_train_multi.shape}")
print(f"X_test  shape: {X_test.shape}")
print(f"y_test_multiclass labels shape: {y_test_multi.shape}")

# print the class distribution of binary_y and y_multiclass
# print the class distribution of binary_y and y_multiclass
print("Multi-class target class distribution (train):")
print(Counter(np.argmax(y_train_multi, axis=1)))
print("Multi-class target class distribution (test):")
print(Counter(np.argmax(y_test_multi, axis=1)))

# scaling the training data
scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

print("Scaling complete.")
# Out:
# X_train shape: (352834, 44)
# y_train_multiclass labels shape: (352834, 9)
# X_test  shape: (88209, 44)
# y_test_multiclass labels shape: (88209, 9)
# Multi-class target class distribution (train):
# Counter({np.int64(5): 240000, np.int64(0): 16000, np.int64(6): 16000, np.int64(7): 16000, np.int64(8): 16000, np.int64(2): 16000, np.int64(1): 16000, np.int64(3): 16000, np.int64(4): 834})
# Multi-class target class distribution (test):
# Counter({np.int64(5): 60000, np.int64(1): 4000, np.int64(3): 4000, np.int64(6): 4000, np.int64(0): 4000, np.int64(8): 4000, np.int64(7): 4000, np.int64(2): 4000, np.int64(4): 209})
# Scaling complete.

# %%
# --- Create Sequences ---
def create_sequences(
    X,
    y,
    window_size: int = 10,
    debug: bool = False,
    trace_limit: int = 5
):
    # Convert to numpy if not already
    X = np.asarray(X)
    y = np.asarray(y)

    # Input validation
    if len(X) != len(y):
        raise ValueError("X and y must have the same number of samples")
    if len(X.shape) != 2:
        raise ValueError("X must be a 2D array: (samples, features)")
    if len(y.shape) > 2:
        raise ValueError("y must be a 1D or 2D array")

    X_seq, y_seq = [], []
    total = len(X) - window_size + 1
    if debug:
        print(f"Total samples: {len(X)} | Generating {total} sequences (window_size={window_size})")

    for i in range(total):
        window = X[i : i + window_size]
        label = y[i + window_size - 1]
        X_seq.append(window)
        y_seq.append(label)

        if debug and i < trace_limit:
            print(f"\n--- Seq {i+1}/{total} ---")
            print(f"  X indices: {i} to {i+window_size-1}")
            print(f"  y index:   {i+window_size-1} → label={label}")
            print(f"  window.shape: {window.shape}")

    if debug:
        print(f"\nTotal sequences generated: {len(X_seq)}")

    return np.array(X_seq), np.array(y_seq)


TIMESTEPS = 10
X_train_seq, y_train_seq = create_sequences(X_train, y_train_multi, window_size=TIMESTEPS, debug=True)
X_test_seq, y_test_seq = create_sequences(X_test, y_test_multi, window_size=TIMESTEPS, debug=True)


print("Train sequence shape:", X_train_seq.shape)  # (samples, timesteps, features)
print("Test sequence shape:", X_test_seq.shape)
print("multi target distribution:", Counter(np.argmax(y_train_multi, axis=1)))

# counters
print("Class distribution in y_train_seq:", Counter(np.argmax(y_train_seq, axis=1)))
print("Class distribution in y_test_seq:", Counter(np.argmax(y_test_seq, axis=1)))

# multiclass sequence generation.
# X_train_seq_multi, y_train_seq_multi = create_sequences(X_train, y_train_multi, debug=True)
# X_test_seq_multi, y_test_seq_multi = create_sequences(X_test, y_test_multi, debug=True)
# Out:
# Total samples: 352834 | Generating 352825 sequences (window_size=10)
#
# --- Seq 1/352825 ---
#   X indices: 0 to 9
#   y index:   9 → label=[0. 0. 0. 0. 0. 0. 0. 1. 0.]
#   window.shape: (10, 44)
#
# --- Seq 2/352825 ---
#   X indices: 1 to 10
#   y index:   10 → label=[0. 0. 0. 0. 0. 1. 0. 0. 0.]
#   window.shape: (10, 44)
#
# --- Seq 3/352825 ---
#   X indices: 2 to 11
#   y index:   11 → label=[0. 0. 0. 0. 0. 0. 0. 0. 1.]
#   window.shape: (10, 44)
#
# --- Seq 4/352825 ---
#   X indices: 3 to 12
#   y index:   12 → label=[0. 0. 0. 0. 0. 1. 0. 0. 0.]
#   window.shape: (10, 44)
#
# --- Seq 5/352825 ---
#   X indices: 4 to 13
#   y index:   13 → label=[0. 0. 0. 0. 0. 1. 0. 0. 0.]
#   window.shape: (10, 44)
#
# Total sequences generated: 352825
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 45
#      41     return np.array(X_seq), np.array(y_seq)
#      44 TIMESTEPS = 10
# ---> 45 X_train_seq, y_train_seq = create_sequences(X_train, y_train_multi, window_size=TIMESTEPS, debug=True)
#      46 X_test_seq, y_test_seq = create_sequences(X_test, y_test_multi, window_size=TIMESTEPS, debug=True)
#      49 print("Train sequence shape:", X_train_seq.shape)  # (samples, timesteps, features)
#
# Cell In[18], line 41, in create_sequences(X, y, window_size, debug, trace_limit)
#      38 if debug:
#      39     print(f"\nTotal sequences generated: {len(X_seq)}")
# ---> 41 return np.array(X_seq), np.array(y_seq)
#
# KeyboardInterrupt:

# %%
from imblearn.over_sampling import ADASYN
from collections import Counter

# Convert one-hot to integer labels for y_train_seq
y_train_seq_labels = np.argmax(y_train_seq, axis=1)

# Apply ADASYN instead of SMOTE
adasyn = ADASYN(
    sampling_strategy={4: 16000},  # Only oversample class 4
    random_state=42,
    n_neighbors=5
)
X_train_res, y_train_res = adasyn.fit_resample(
	X_train_seq.reshape(X_train_seq.shape[0], -1),  # Flatten for ADASYN
	y_train_seq_labels
)
X_train_res = X_train_res.reshape(X_train_res.shape[0], TIMESTEPS, X_train_seq.shape[2])  # Reshape back to sequences
y_train_res = to_categorical(y_train_res, num_classes=y_train_seq.shape[1])  # One-hot encode	
print("After ADASYN:")
print("Resampled X_train shape:", X_train_res.shape)
print("Resampled y_train shape:", y_train_res.shape)
print("Resampled class distribution:", Counter(np.argmax(y_train_res, axis=1)))
# Out:
# After ADASYN:
# Resampled X_train shape: (367686, 10, 44)
# Resampled y_train shape: (367686, 9)
# Resampled class distribution: Counter({np.int64(5): 239994, np.int64(8): 16000, np.int64(2): 16000, np.int64(1): 16000, np.int64(3): 16000, np.int64(7): 15999, np.int64(6): 15999, np.int64(0): 15999, np.int64(4): 15695})

# %%
from sklearn.utils import shuffle

# Without SMOTE X_train_seq, y_train_seq
# X_train_seq_bal_shuffle, y_train_seq_bal_shuffle = shuffle(X_train_seq, y_train_seq, random_state=42)

# SMOTE on X_train_res, y_train_res
X_train_seq_bal_shuffle, y_train_seq_bal_shuffle = shuffle(X_train_res, y_train_res, random_state=42)

val_fraction = 0.2
n_total = X_train_seq_bal_shuffle.shape[0]
n_val = int(n_total * val_fraction)

X_val_seq = X_train_seq_bal_shuffle[-n_val:]
y_val_seq = y_train_seq_bal_shuffle[-n_val:]
X_train_seq_final = X_train_seq_bal_shuffle[:-n_val]
y_train_seq_final = y_train_seq_bal_shuffle[:-n_val]

print("Final training shapes:")
print(f"X_train_seq_final shape: {X_train_seq_final.shape}")
print(f"y_train_seq_final shape: {y_train_seq_final.shape}")
print(f"X_val_seq shape: {X_val_seq.shape}")
print(f"y_val_seq shape: {y_val_seq.shape}")

print("Final training label distributions:")
print(f"y_train_seq_final distribution: {Counter(np.argmax(y_train_seq_final, axis=1))}")
print(f"y_val_seq distribution: {Counter(np.argmax(y_val_seq, axis=1))}")
# Out:
# Final training shapes:
# X_train_seq_final shape: (294149, 10, 44)
# y_train_seq_final shape: (294149, 9)
# X_val_seq shape: (73537, 10, 44)
# y_val_seq shape: (73537, 9)
# Final training label distributions:
# y_train_seq_final distribution: Counter({np.int64(5): 191822, np.int64(2): 12856, np.int64(1): 12850, np.int64(7): 12825, np.int64(0): 12822, np.int64(3): 12815, np.int64(8): 12784, np.int64(6): 12759, np.int64(4): 12616})
# y_val_seq distribution: Counter({np.int64(5): 48172, np.int64(6): 3240, np.int64(8): 3216, np.int64(3): 3185, np.int64(0): 3177, np.int64(7): 3174, np.int64(1): 3150, np.int64(2): 3144, np.int64(4): 3079})

# %%
from tensorflow.keras.metrics import Metric


def focal_loss(gamma=2., alpha=0.25):
    def loss(y_true, y_pred):
        y_true = tf.cast(y_true, tf.float32)
        y_pred = tf.cast(y_pred, tf.float32)
        
        # Clip predictions to avoid log(0)
        y_pred = tf.clip_by_value(y_pred, 1e-7, 1.0 - 1e-7)
        
        # Compute cross entropy
        ce = -y_true * tf.math.log(y_pred)
        
        # Compute focal weight
        weight = alpha * tf.pow(1 - y_pred, gamma)
        
        # Apply focal loss
        fl = weight * ce
        
        # Reduce across classes and samples
        return tf.reduce_mean(tf.reduce_sum(fl, axis=-1))
    
    return loss

class MultiClassGMeanMetric(Metric):
    def __init__(self, num_classes, name='multi_class_gmean', **kwargs):
        super(MultiClassGMeanMetric, self).__init__(name=name, **kwargs)
        self.num_classes = num_classes
        # Store TP, TN, FP, FN for each class
        self.tp = [self.add_weight(name=f'tp_{i}', initializer='zeros') 
                  for i in range(num_classes)]
        self.tn = [self.add_weight(name=f'tn_{i}', initializer='zeros') 
                  for i in range(num_classes)]
        self.fp = [self.add_weight(name=f'fp_{i}', initializer='zeros') 
                  for i in range(num_classes)]
        self.fn = [self.add_weight(name=f'fn_{i}', initializer='zeros') 
                  for i in range(num_classes)]

    def update_state(self, y_true, y_pred, sample_weight=None):
        y_pred_labels = tf.argmax(y_pred, axis=1)
        y_true_labels = tf.argmax(y_true, axis=1)
        
        for i in range(self.num_classes):
            # One-vs-rest for each class
            true_pos = tf.logical_and(
                tf.equal(y_true_labels, i), 
                tf.equal(y_pred_labels, i)
            )
            true_neg = tf.logical_and(
                tf.not_equal(y_true_labels, i), 
                tf.not_equal(y_pred_labels, i)
            )
            false_pos = tf.logical_and(
                tf.not_equal(y_true_labels, i), 
                tf.equal(y_pred_labels, i)
            )
            false_neg = tf.logical_and(
                tf.equal(y_true_labels, i), 
                tf.not_equal(y_pred_labels, i)
            )
            
            self.tp[i].assign_add(tf.reduce_sum(tf.cast(true_pos, tf.float32)))
            self.tn[i].assign_add(tf.reduce_sum(tf.cast(true_neg, tf.float32)))
            self.fp[i].assign_add(tf.reduce_sum(tf.cast(false_pos, tf.float32)))
            self.fn[i].assign_add(tf.reduce_sum(tf.cast(false_neg, tf.float32)))

    def result(self):
        gmeans = []
        for i in range(self.num_classes):
            sensitivity = self.tp[i] / (self.tp[i] + self.fn[i] + tf.keras.backend.epsilon())
            specificity = self.tn[i] / (self.tn[i] + self.fp[i] + tf.keras.backend.epsilon())
            gmean = tf.sqrt(sensitivity * specificity)
            gmeans.append(gmean)
        
        # Macro-average: average of per-class G-means
        return tf.reduce_mean(gmeans)

    def reset_states(self):
        for var in self.variables:
            var.assign(0)
        for var in self.variables:
            var.assign(0)

# %%
# calculate class weight using median fequency
def compute_balanced_weights(y_labels, clip_max=5.0):
    # y_labels: 1D array of integer class labels for training samples
    N = len(y_labels)
    K = len(np.unique(y_labels))
    counts = Counter(y_labels)
    cw = {cls: N / (K * counts[cls]) for cls in counts}
    # clip
    cw = {cls: min(w, clip_max) for cls, w in cw.items()}
    return cw

# use on integer labels
y_train_labels = np.argmax(y_train_seq_final, axis=1)
class_weights = compute_balanced_weights(y_train_labels, clip_max=5.0)
print("Class weights:", class_weights)
# Out:
# Class weights: {np.int64(5): 0.17038307504990158, np.int64(8): 2.556572451675706, np.int64(2): 2.5422543732282374, np.int64(0): 2.548995649837952, np.int64(1): 2.5434414180717684, np.int64(3): 2.550388000173408, np.int64(4): 2.590616853378426, np.int64(6): 2.5615818028232793, np.int64(7): 2.5483993935455924}

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Bidirectional, LSTM, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from sklearn.utils.class_weight import compute_class_weight
from tensorflow.keras.metrics import Precision
from tensorflow.keras.layers import LayerNormalization
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import Recall, AUC
from sklearn.metrics import (confusion_matrix, accuracy_score, recall_score, precision_score, f1_score, matthews_corrcoef, roc_auc_score, classification_report, roc_curve, precision_recall_curve)
import matplotlib.pyplot as plt
from tensorflow.keras.optimizers.schedules import CosineDecayRestarts


# Model definition
model = Sequential([
    Bidirectional(LSTM(
        128,                       
        return_sequences=True,
        recurrent_dropout=0.15,
        recurrent_activation='sigmoid',
        activation='tanh',
        kernel_regularizer=l2(1e-5)
    ), input_shape=(X_train_seq.shape[1], X_train_seq.shape[2])),
    LayerNormalization(),
    Dropout(0.3),

    Bidirectional(LSTM(
        64,
        recurrent_dropout=0.15,
        recurrent_activation='sigmoid', 
        activation='tanh',
        kernel_regularizer=l2(1e-5)
    )),
    LayerNormalization(),
    Dropout(0.3),

    Dense(64, activation='relu', kernel_regularizer=l2(1e-5)),
    Dropout(0.25),

    Dense(32, activation='relu'),
    Dropout(0.2),

    Dense(9, activation='softmax')
])

model.summary()

lr_schedule = CosineDecayRestarts(initial_learning_rate=1e-3, first_decay_steps=5)
optimizer = Adam(learning_rate=lr_schedule, clipnorm=1.0)

optimizer = Adam(
    learning_rate=0.0001,  # Very low initial LR 0.0002 <> 0.0001
    clipnorm=1.0,  # Gradient clipping to prevent exploding gradients
)

model.compile(
    optimizer=optimizer,
    loss=focal_loss(gamma=2.0, alpha=0.45),
    metrics=[
        'accuracy', 
        AUC(name='auc'), 
        Recall(), 
        Precision(), 
        MultiClassGMeanMetric(num_classes=y_train_seq_final.shape[1])
    ])

# Early stopping
early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=3,
    mode='min',
    restore_best_weights=True,
    verbose=1
)

# frequencies = np.sum(y_train_seq_final, axis=0)
# median_freq = np.median(frequencies)
# class_weights = {cls: median_freq / count for cls, count in enumerate(frequencies)}

print("Class weights:", class_weights)
# Train
history = model.fit(
    X_train_seq_final, y_train_seq_final,
    validation_data=(X_val_seq, y_val_seq),
    epochs=50,
    batch_size=128,
    shuffle=False,
    callbacks=[early_stopping],
    class_weight=class_weights,
    verbose=1
)

results = model.evaluate(X_test_seq, y_test_seq, verbose=2)

print("Test Loss: {}".format(results[0]))
print("Test Accuracy: {}".format(results[1]))
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1765627464.643093   18491 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 2278 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 2050, pci bus id: 0000:01:00.0, compute capability: 8.6
# /home/jinesh-subedi/htdocs/thesis/thesisStudy/lib/python3.12/site-packages/keras/src/layers/rnn/bidirectional.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ bidirectional (Bidirectional)   │ (None, 10, 256)        │       177,152 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ layer_normalization             │ (None, 10, 256)        │           512 │
# │ (LayerNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 10, 256)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_1 (Bidirectional) │ (None, 128)            │       164,352 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ layer_normalization_1           │ (None, 128)            │           256 │
# │ (LayerNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 9)              │           297 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 352,905 (1.35 MB)
#  Trainable params: 352,905 (1.35 MB)
#  Non-trainable params: 0 (0.00 B)
# Class weights: {np.int64(5): 0.17038307504990158, np.int64(8): 2.556572451675706, np.int64(2): 2.5422543732282374, np.int64(0): 2.548995649837952, np.int64(1): 2.5434414180717684, np.int64(3): 2.550388000173408, np.int64(4): 2.590616853378426, np.int64(6): 2.5615818028232793, np.int64(7): 2.5483993935455924}
# Epoch 1/50
# 2299/2299 ━━━━━━━━━━━━━━━━━━━━ 112s 44ms/step - accuracy: 0.6326 - auc: 0.9050 - loss: 0.3730 - multi_class_gmean: 0.3776 - precision: 0.8722 - recall: 0.4282 - val_accuracy: 0.7656 - val_auc: 0.9769 - val_loss: 0.1675 - val_multi_class_gmean: 0.5961 - val_precision: 0.9539 - val_recall: 0.6228
# Epoch 2/50
# 2299/2299 ━━━━━━━━━━━━━━━━━━━━ 100s 44ms/step - accuracy: 0.7462 - auc: 0.9684 - loss: 0.1890 - multi_class_gmean: 0.6412 - precision: 0.9073 - recall: 0.6246 - val_accuracy: 0.8184 - val_auc: 0.9845 - val_loss: 0.1214 - val_multi_class_gmean: 0.7552 - val_precision: 0.9448 - val_recall: 0.6935
# Epoch 3/50
# 2299/2299 ━━━━━━━━━━━━━━━━━━━━ 100s 44ms/step - accuracy: 0.8030 - auc: 0.9801 - loss: 0.1394 - multi_class_gmean: 0.7461 - precision: 0.9136 - recall: 0.6919 - val_accuracy: 0.8812 - val_auc: 0.9919 - val_loss: 0.0788 - val_multi_class_gmean: 0.8679 - val_precision: 0.9310 - val_recall: 0.8162
# Epoch 4/50
# 2299/2299 ━━━━━━━━━━━━━━━━━━━━ 101s 44ms/step - accuracy: 0.8491 - auc: 0.9872 - loss: 0.1038 - multi_class_gmean: 0.8234 - precision: 0.9134 - recall: 0.7656 - val_accuracy: 0.9151 - val_auc: 0.9952 - val_loss: 0.0565 - val_multi_class_gmean: 0.9186 - val_precision: 0.9458 - val_recall: 0.8952
# Epoch 5/50
# 2299/2299 ━━━━━━━━━━━━━━━━━━━━ 101s 44ms/step - accuracy: 0.8753 - auc: 0.9911 - loss: 0.0807 - multi_class_gmean: 0.8626 - precision: 0.9186 - recall: 0.8133 - val_accuracy: 0.9270 - val_auc: 0.9966 - val_loss: 0.0452 - val_multi_class_gmean: 0.9345 - val_precision: 0.9476 - val_recall: 0.9074
# Epoch 6/50
# 2299/2299 ━━━━━━━━━━━━━━━━━━━━ 101s 44ms/step - accuracy: 0.8917 - auc: 0.9931 - loss: 0.0674 - multi_class_gmean: 0.8852 - precision: 0.9264 - recall: 0.8427 - val_accuracy: 0.9400 - val_auc: 0.9973 - val_loss: 0.0386 - val_multi_class_gmean: 0.9550 - val_precision: 0.9564 - val_recall: 0.9232
# Epoch 7/50
# 2299/2299 ━━━━━━━━━━━━━━━━━━━━ 104s 45ms/step - accuracy: 0.9041 - auc: 0.9944 - loss: 0.0586 - multi_class_gmean: 0.9006 - precision: 0.9334 - recall: 0.8632 - val_accuracy: 0.9498 - val_auc: 0.9979 - val_loss: 0.0331 - val_multi_class_gmean: 0.9614 - val_precision: 0.9623 - val_recall: 0.9362
# Epoch 8/50
# 2299/2299 ━━━━━━━━━━━━━━━━━━━━ 104s 45ms/step - accuracy: 0.9145 - auc: 0.9955 - loss: 0.0514 - multi_class_gmean: 0.9126 - precision: 0.9389 - recall: 0.8797 - val_accuracy: 0.9547 - val_auc: 0.9982 - val_loss: 0.0300 - val_multi_class_gmean: 0.9635 - val_precision: 0.9675 - val_recall: 0.9394
# Epoch 9/50
# 2299/2299 ━━━━━━━━━━━━━━━━━━━━ 104s 45ms/step - accuracy: 0.9235 - auc: 0.9962 - loss: 0.0458 - multi_class_gmean: 0.9225 - precision: 0.9444 - recall: 0.8946 - val_accuracy: 0.9642 - val_auc: 0.9985 - val_loss: 0.0265 - val_multi_class_gmean: 0.9725 - val_precision: 0.9742 - val_recall: 0.9571
# Epoch 10/50
# 2299/2299 ━━━━━━━━━━━━━━━━━━━━ 104s 45ms/step - accuracy: 0.9302 - auc: 0.9967 - loss: 0.0419 - multi_class_gmean: 0.9296 - precision: 0.9482 - recall: 0.9048 - val_accuracy: 0.9660 - val_auc: 0.9987 - val_loss: 0.0244 - val_multi_class_gmean: 0.9743 - val_precision: 0.9752 - val_recall: 0.9581
# Epoch 11/50
# 2299/2299 ━━━━━━━━━━━━━━━━━━━━ 104s 45ms/step - accuracy: 0.9356 - auc: 0.9972 - loss: 0.0388 - multi_class_gmean: 0.9356 - precision: 0.9519 - recall: 0.9129 - val_accuracy: 0.9689 - val_auc: 0.9989 - val_loss: 0.0226 - val_multi_class_gmean: 0.9770 - val_precision: 0.9764 - val_recall: 0.9585
# Epoch 12/50
# 2299/2299 ━━━━━━━━━━━━━━━━━━━━ 104s 45ms/step - accuracy: 0.9403 - auc: 0.9975 - loss: 0.0359 - multi_class_gmean: 0.9406 - precision: 0.9551 - recall: 0.9197 - val_accuracy: 0.9688 - val_auc: 0.9990 - val_loss: 0.0216 - val_multi_class_gmean: 0.9764 - val_precision: 0.9765 - val_recall: 0.9633
# Epoch 13/50
# 2299/2299 ━━━━━━━━━━━━━━━━━━━━ 104s 45ms/step - accuracy: 0.9439 - auc: 0.9977 - loss: 0.0340 - multi_class_gmean: 0.9442 - precision: 0.9576 - recall: 0.9250 - val_accuracy: 0.9726 - val_auc: 0.9991 - val_loss: 0.0199 - val_multi_class_gmean: 0.9815 - val_precision: 0.9786 - val_recall: 0.9653
# Epoch 14/50
# 2299/2299 ━━━━━━━━━━━━━━━━━━━━ 104s 45ms/step - accuracy: 0.9472 - auc: 0.9979 - loss: 0.0318 - multi_class_gmean: 0.9486 - precision: 0.9598 - recall: 0.9299 - val_accuracy: 0.9741 - val_auc: 0.9992 - val_loss: 0.0189 - val_multi_class_gmean: 0.9825 - val_precision: 0.9792 - val_recall: 0.9687
# Epoch 15/50
# 2299/2299 ━━━━━━━━━━━━━━━━━━━━ 105s 46ms/step - accuracy: 0.9499 - auc: 0.9981 - loss: 0.0302 - multi_class_gmean: 0.9517 - precision: 0.9615 - recall: 0.9336 - val_accuracy: 0.9746 - val_auc: 0.9992 - val_loss: 0.0184 - val_multi_class_gmean: 0.9832 - val_precision: 0.9800 - val_recall: 0.9689
# Epoch 16/50
# 2299/2299 ━━━━━━━━━━━━━━━━━━━━ 105s 46ms/step - accuracy: 0.9523 - auc: 0.9982 - loss: 0.0291 - multi_class_gmean: 0.9544 - precision: 0.9630 - recall: 0.9377 - val_accuracy: 0.9722 - val_auc: 0.9993 - val_loss: 0.0179 - val_multi_class_gmean: 0.9793 - val_precision: 0.9770 - val_recall: 0.9683
# Epoch 17/50
# 2299/2299 ━━━━━━━━━━━━━━━━━━━━ 105s 46ms/step - accuracy: 0.9543 - auc: 0.9984 - loss: 0.0277 - multi_class_gmean: 0.9567 - precision: 0.9645 - recall: 0.9405 - val_accuracy: 0.9766 - val_auc: 0.9993 - val_loss: 0.0170 - val_multi_class_gmean: 0.9853 - val_precision: 0.9807 - val_recall: 0.9724
# Epoch 18/50
# 2299/2299 ━━━━━━━━━━━━━━━━━━━━ 105s 46ms/step - accuracy: 0.9562 - auc: 0.9985 - loss: 0.0267 - multi_class_gmean: 0.9591 - precision: 0.9657 - recall: 0.9434 - val_accuracy: 0.9754 - val_auc: 0.9994 - val_loss: 0.0164 - val_multi_class_gmean: 0.9833 - val_precision: 0.9797 - val_recall: 0.9716
# Epoch 19/50
# 2299/2299 ━━━━━━━━━━━━━━━━━━━━ 105s 46ms/step - accuracy: 0.9578 - auc: 0.9986 - loss: 0.0259 - multi_class_gmean: 0.9608 - precision: 0.9667 - recall: 0.9451 - val_accuracy: 0.9763 - val_auc: 0.9994 - val_loss: 0.0158 - val_multi_class_gmean: 0.9849 - val_precision: 0.9801 - val_recall: 0.9719
# Epoch 20/50
# 2299/2299 ━━━━━━━━━━━━━━━━━━━━ 105s 46ms/step - accuracy: 0.9596 - auc: 0.9986 - loss: 0.0248 - multi_class_gmean: 0.9627 - precision: 0.9680 - recall: 0.9481 - val_accuracy: 0.9783 - val_auc: 0.9995 - val_loss: 0.0154 - val_multi_class_gmean: 0.9883 - val_precision: 0.9815 - val_recall: 0.9736
# Epoch 21/50
# 2299/2299 ━━━━━━━━━━━━━━━━━━━━ 105s 46ms/step - accuracy: 0.9608 - auc: 0.9987 - loss: 0.0239 - multi_class_gmean: 0.9642 - precision: 0.9689 - recall: 0.9497 - val_accuracy: 0.9762 - val_auc: 0.9994 - val_loss: 0.0152 - val_multi_class_gmean: 0.9842 - val_precision: 0.9798 - val_recall: 0.9727
# Epoch 22/50
# 2299/2299 ━━━━━━━━━━━━━━━━━━━━ 106s 46ms/step - accuracy: 0.9619 - auc: 0.9988 - loss: 0.0233 - multi_class_gmean: 0.9658 - precision: 0.9699 - recall: 0.9517 - val_accuracy: 0.9767 - val_auc: 0.9995 - val_loss: 0.0148 - val_multi_class_gmean: 0.9842 - val_precision: 0.9803 - val_recall: 0.9727
# Epoch 23/50
# 2299/2299 ━━━━━━━━━━━━━━━━━━━━ 106s 46ms/step - accuracy: 0.9629 - auc: 0.9988 - loss: 0.0228 - multi_class_gmean: 0.9667 - precision: 0.9705 - recall: 0.9533 - val_accuracy: 0.9786 - val_auc: 0.9995 - val_loss: 0.0144 - val_multi_class_gmean: 0.9857 - val_precision: 0.9819 - val_recall: 0.9750
# Epoch 24/50
# 2299/2299 ━━━━━━━━━━━━━━━━━━━━ 106s 46ms/step - accuracy: 0.9639 - auc: 0.9989 - loss: 0.0221 - multi_class_gmean: 0.9677 - precision: 0.9711 - recall: 0.9544 - val_accuracy: 0.9785 - val_auc: 0.9995 - val_loss: 0.0141 - val_multi_class_gmean: 0.9869 - val_precision: 0.9820 - val_recall: 0.9749
# Epoch 25/50
# 2299/2299 ━━━━━━━━━━━━━━━━━━━━ 106s 46ms/step - accuracy: 0.9651 - auc: 0.9989 - loss: 0.0216 - multi_class_gmean: 0.9688 - precision: 0.9720 - recall: 0.9563 - val_accuracy: 0.9794 - val_auc: 0.9995 - val_loss: 0.0140 - val_multi_class_gmean: 0.9886 - val_precision: 0.9823 - val_recall: 0.9759
# Epoch 26/50
# 2299/2299 ━━━━━━━━━━━━━━━━━━━━ 106s 46ms/step - accuracy: 0.9656 - auc: 0.9990 - loss: 0.0211 - multi_class_gmean: 0.9694 - precision: 0.9724 - recall: 0.9568 - val_accuracy: 0.9809 - val_auc: 0.9996 - val_loss: 0.0134 - val_multi_class_gmean: 0.9891 - val_precision: 0.9844 - val_recall: 0.9774
# Epoch 27/50
# 2299/2299 ━━━━━━━━━━━━━━━━━━━━ 106s 46ms/step - accuracy: 0.9667 - auc: 0.9990 - loss: 0.0205 - multi_class_gmean: 0.9710 - precision: 0.9731 - recall: 0.9587 - val_accuracy: 0.9753 - val_auc: 0.9995 - val_loss: 0.0144 - val_multi_class_gmean: 0.9799 - val_precision: 0.9784 - val_recall: 0.9715
# Epoch 28/50
# 2299/2299 ━━━━━━━━━━━━━━━━━━━━ 106s 46ms/step - accuracy: 0.9667 - auc: 0.9991 - loss: 0.0203 - multi_class_gmean: 0.9710 - precision: 0.9731 - recall: 0.9588 - val_accuracy: 0.9805 - val_auc: 0.9996 - val_loss: 0.0130 - val_multi_class_gmean: 0.9880 - val_precision: 0.9838 - val_recall: 0.9770
# Epoch 29/50
# 2299/2299 ━━━━━━━━━━━━━━━━━━━━ 107s 46ms/step - accuracy: 0.9680 - auc: 0.9991 - loss: 0.0197 - multi_class_gmean: 0.9725 - precision: 0.9742 - recall: 0.9605 - val_accuracy: 0.9793 - val_auc: 0.9996 - val_loss: 0.0131 - val_multi_class_gmean: 0.9864 - val_precision: 0.9827 - val_recall: 0.9753
# Epoch 30/50
# 2299/2299 ━━━━━━━━━━━━━━━━━━━━ 107s 46ms/step - accuracy: 0.9688 - auc: 0.9991 - loss: 0.0195 - multi_class_gmean: 0.9732 - precision: 0.9746 - recall: 0.9609 - val_accuracy: 0.9770 - val_auc: 0.9995 - val_loss: 0.0134 - val_multi_class_gmean: 0.9840 - val_precision: 0.9805 - val_recall: 0.9736
# Epoch 31/50
# 2299/2299 ━━━━━━━━━━━━━━━━━━━━ 106s 46ms/step - accuracy: 0.9687 - auc: 0.9991 - loss: 0.0194 - multi_class_gmean: 0.9732 - precision: 0.9744 - recall: 0.9614 - val_accuracy: 0.9806 - val_auc: 0.9996 - val_loss: 0.0126 - val_multi_class_gmean: 0.9878 - val_precision: 0.9834 - val_recall: 0.9767
# Epoch 32/50
# 2299/2299 ━━━━━━━━━━━━━━━━━━━━ 107s 46ms/step - accuracy: 0.9698 - auc: 0.9991 - loss: 0.0189 - multi_class_gmean: 0.9743 - precision: 0.9753 - recall: 0.9625 - val_accuracy: 0.9822 - val_auc: 0.9996 - val_loss: 0.0126 - val_multi_class_gmean: 0.9905 - val_precision: 0.9853 - val_recall: 0.9787
# Epoch 33/50
# 2299/2299 ━━━━━━━━━━━━━━━━━━━━ 107s 47ms/step - accuracy: 0.9700 - auc: 0.9992 - loss: 0.0185 - multi_class_gmean: 0.9743 - precision: 0.9756 - recall: 0.9631 - val_accuracy: 0.9786 - val_auc: 0.9996 - val_loss: 0.0128 - val_multi_class_gmean: 0.9853 - val_precision: 0.9812 - val_recall: 0.9749
# Epoch 34/50
# 2299/2299 ━━━━━━━━━━━━━━━━━━━━ 107s 46ms/step - accuracy: 0.9700 - auc: 0.9992 - loss: 0.0184 - multi_class_gmean: 0.9746 - precision: 0.9753 - recall: 0.9632 - val_accuracy: 0.9826 - val_auc: 0.9996 - val_loss: 0.0121 - val_multi_class_gmean: 0.9911 - val_precision: 0.9855 - val_recall: 0.9791
# Epoch 35/50
# 2299/2299 ━━━━━━━━━━━━━━━━━━━━ 107s 47ms/step - accuracy: 0.9706 - auc: 0.9992 - loss: 0.0181 - multi_class_gmean: 0.9753 - precision: 0.9759 - recall: 0.9637 - val_accuracy: 0.9834 - val_auc: 0.9997 - val_loss: 0.0117 - val_multi_class_gmean: 0.9923 - val_precision: 0.9857 - val_recall: 0.9797
# Epoch 36/50
# 2299/2299 ━━━━━━━━━━━━━━━━━━━━ 107s 47ms/step - accuracy: 0.9712 - auc: 0.9992 - loss: 0.0178 - multi_class_gmean: 0.9758 - precision: 0.9762 - recall: 0.9644 - val_accuracy: 0.9841 - val_auc: 0.9997 - val_loss: 0.0114 - val_multi_class_gmean: 0.9927 - val_precision: 0.9864 - val_recall: 0.9805
# Epoch 37/50
# 2299/2299 ━━━━━━━━━━━━━━━━━━━━ 107s 47ms/step - accuracy: 0.9718 - auc: 0.9993 - loss: 0.0174 - multi_class_gmean: 0.9765 - precision: 0.9766 - recall: 0.9654 - val_accuracy: 0.9815 - val_auc: 0.9997 - val_loss: 0.0118 - val_multi_class_gmean: 0.9889 - val_precision: 0.9834 - val_recall: 0.9782
# Epoch 38/50
# 2299/2299 ━━━━━━━━━━━━━━━━━━━━ 108s 47ms/step - accuracy: 0.9716 - auc: 0.9993 - loss: 0.0174 - multi_class_gmean: 0.9764 - precision: 0.9765 - recall: 0.9654 - val_accuracy: 0.9836 - val_auc: 0.9997 - val_loss: 0.0114 - val_multi_class_gmean: 0.9918 - val_precision: 0.9856 - val_recall: 0.9800
# Epoch 39/50
# 2299/2299 ━━━━━━━━━━━━━━━━━━━━ 121s 53ms/step - accuracy: 0.9726 - auc: 0.9993 - loss: 0.0169 - multi_class_gmean: 0.9773 - precision: 0.9771 - recall: 0.9666 - val_accuracy: 0.9839 - val_auc: 0.9997 - val_loss: 0.0113 - val_multi_class_gmean: 0.9931 - val_precision: 0.9860 - val_recall: 0.9804
# Epoch 40/50
# 2299/2299 ━━━━━━━━━━━━━━━━━━━━ 128s 56ms/step - accuracy: 0.9727 - auc: 0.9993 - loss: 0.0170 - multi_class_gmean: 0.9775 - precision: 0.9773 - recall: 0.9669 - val_accuracy: 0.9809 - val_auc: 0.9997 - val_loss: 0.0116 - val_multi_class_gmean: 0.9878 - val_precision: 0.9836 - val_recall: 0.9784
# Epoch 41/50
# 2299/2299 ━━━━━━━━━━━━━━━━━━━━ 139s 61ms/step - accuracy: 0.9737 - auc: 0.9993 - loss: 0.0166 - multi_class_gmean: 0.9784 - precision: 0.9780 - recall: 0.9677 - val_accuracy: 0.9823 - val_auc: 0.9997 - val_loss: 0.0111 - val_multi_class_gmean: 0.9905 - val_precision: 0.9842 - val_recall: 0.9799
# Epoch 42/50
# 2299/2299 ━━━━━━━━━━━━━━━━━━━━ 143s 62ms/step - accuracy: 0.9732 - auc: 0.9993 - loss: 0.0166 - multi_class_gmean: 0.9779 - precision: 0.9777 - recall: 0.9674 - val_accuracy: 0.9835 - val_auc: 0.9997 - val_loss: 0.0110 - val_multi_class_gmean: 0.9926 - val_precision: 0.9858 - val_recall: 0.9803
# Epoch 43/50
# 2299/2299 ━━━━━━━━━━━━━━━━━━━━ 145s 63ms/step - accuracy: 0.9738 - auc: 0.9993 - loss: 0.0163 - multi_class_gmean: 0.9788 - precision: 0.9781 - recall: 0.9682 - val_accuracy: 0.9840 - val_auc: 0.9997 - val_loss: 0.0107 - val_multi_class_gmean: 0.9920 - val_precision: 0.9867 - val_recall: 0.9817
# Epoch 44/50
# 2299/2299 ━━━━━━━━━━━━━━━━━━━━ 146s 63ms/step - accuracy: 0.9741 - auc: 0.9993 - loss: 0.0160 - multi_class_gmean: 0.9791 - precision: 0.9785 - recall: 0.9685 - val_accuracy: 0.9849 - val_auc: 0.9997 - val_loss: 0.0106 - val_multi_class_gmean: 0.9932 - val_precision: 0.9865 - val_recall: 0.9815
# Epoch 45/50
# 2299/2299 ━━━━━━━━━━━━━━━━━━━━ 147s 64ms/step - accuracy: 0.9742 - auc: 0.9993 - loss: 0.0160 - multi_class_gmean: 0.9790 - precision: 0.9786 - recall: 0.9687 - val_accuracy: 0.9826 - val_auc: 0.9997 - val_loss: 0.0107 - val_multi_class_gmean: 0.9903 - val_precision: 0.9845 - val_recall: 0.9797
# Epoch 46/50
# 2299/2299 ━━━━━━━━━━━━━━━━━━━━ 149s 65ms/step - accuracy: 0.9746 - auc: 0.9994 - loss: 0.0159 - multi_class_gmean: 0.9793 - precision: 0.9787 - recall: 0.9692 - val_accuracy: 0.9812 - val_auc: 0.9997 - val_loss: 0.0112 - val_multi_class_gmean: 0.9871 - val_precision: 0.9834 - val_recall: 0.9792
# Epoch 47/50
# 2299/2299 ━━━━━━━━━━━━━━━━━━━━ 152s 66ms/step - accuracy: 0.9745 - auc: 0.9994 - loss: 0.0157 - multi_class_gmean: 0.9792 - precision: 0.9787 - recall: 0.9693 - val_accuracy: 0.9833 - val_auc: 0.9997 - val_loss: 0.0107 - val_multi_class_gmean: 0.9907 - val_precision: 0.9853 - val_recall: 0.9796
# Epoch 47: early stopping
# Restoring model weights from the end of the best epoch: 44.
# 2757/2757 - 29s - 10ms/step - accuracy: 0.9847 - auc: 0.9998 - loss: 0.0106 - multi_class_gmean: 0.9922 - precision: 0.9864 - recall: 0.9814
# Test Loss: 0.010591312311589718
# Test Accuracy: 0.9847279191017151

# %%
import seaborn as sns

# original class labels (what was in df[TARGET_TYPE])
print(type_encoder.classes_)

# numeric codes assigned
for i, cls in enumerate(type_encoder.classes_):
    print(f"Encoded class {i} -> {cls}")


# Print classification report
y_pred_probs = model.predict(X_test_seq)
y_pred_classes = y_pred_probs.argmax(axis=1)
y_true_classes = y_test_seq.argmax(axis=1)
print(classification_report(y_true_classes, y_pred_classes))

#confusion matrix
cm = confusion_matrix(y_true_classes, y_pred_classes)

# For multi-class, FNR and FPR are not simply tn, fp, fn, tp.
# If you want per-class FNR/FPR:
fnr = []
fpr = []
for i in range(cm.shape[0]):
    fn = cm[i, :].sum() - cm[i, i]
    tp = cm[i, i]
    fp = cm[:, i].sum() - cm[i, i]
    tn = cm.sum() - (tp + fn + fp)
    fnr.append(fn / (fn + tp) if (fn + tp) > 0 else 0)
    fpr.append(fp / (fp + tn) if (fp + tn) > 0 else 0)

results_df = pd.DataFrame({
    "Class": type_encoder.classes_,
    "FNR": fnr,
    "FPR": fpr
})
print(results_df.to_string(index=False))


# Plot confusion matrix
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=type_encoder.classes_,
            yticklabels=type_encoder.classes_)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()


# plot validation loss and accuracy
plt.figure(figsize=(12, 6))
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Loss and Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Loss/Accuracy')
plt.legend()
plt.show()

# sensitivity vs 1-specificity plot for multi-class
plt.figure(figsize=(8, 6))
for i in range(len(type_encoder.classes_)):
    fpr_i, tpr_i, _ = roc_curve(y_test_seq[:, i], y_pred_probs[:, i])
    plt.plot(fpr_i, tpr_i, label=f'Class {type_encoder.classes_[i]} (AUC = {roc_auc_score(y_test_seq[:, i], y_pred_probs[:, i]):.2f})')
plt.plot([0, 1], [0, 1], 'k--')  # Diagonal line
plt.title('Multi-class ROC Curve')
plt.xlabel('1 - Specificity (FPR)')
plt.ylabel('Sensitivity (TPR)')
plt.legend()
plt.show()  

# precision-recall curve for multi-class
plt.figure(figsize=(8, 6))
for i in range(len(type_encoder.classes_)):
    precision_i, recall_i, _ = precision_recall_curve(y_test_seq[:, i], y_pred_probs[:, i])
    plt.plot(recall_i, precision_i, label=f'Class {type_encoder.classes_[i]}')
plt.title('Multi-class Precision-Recall Curve')
plt.xlabel('Recall')
plt.ylabel('Precision') 
plt.legend()
plt.show()

# gmean history
plt.figure(figsize=(12, 6))
plt.plot(history.history['multi_class_gmean'], label='Train G-Mean')
plt.plot(history.history['val_multi_class_gmean'], label='Validation G-Mean')
plt.title('Final Model Training and Validation G-Mean')
plt.xlabel('Epoch')
plt.ylabel('G-Mean')
plt.legend()
plt.show()
# Out:
# ['backdoor' 'ddos' 'dos' 'injection' 'mitm' 'normal' 'password' 'scanning'
#  'xss']
# Encoded class 0 -> backdoor
# Encoded class 1 -> ddos
# Encoded class 2 -> dos
# Encoded class 3 -> injection
# Encoded class 4 -> mitm
# Encoded class 5 -> normal
# Encoded class 6 -> password
# Encoded class 7 -> scanning
# Encoded class 8 -> xss
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 25s 9ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      3999
#            1       0.94      0.99      0.97      3999
#            2       0.98      0.96      0.97      4000
#            3       0.97      1.00      0.98      3999
#            4       0.34      0.97      0.51       209
#            5       1.00      0.98      0.99     59995
#            6       0.96      1.00      0.98      3999
#            7       0.98      1.00      0.99      4000
#            8       0.98      0.98      0.98      4000
#
#     accuracy                           0.98     88200
#    macro avg       0.91      0.99      0.93     88200
# weighted avg       0.99      0.98      0.99     88200
#
#     Class      FNR      FPR
#  backdoor 0.000000 0.000143
#      ddos 0.007752 0.002933
#       dos 0.037250 0.000713
# injection 0.004501 0.001675
#      mitm 0.028708 0.004432
#    normal 0.017435 0.007197
#  password 0.004001 0.001722
#  scanning 0.004000 0.001033
#       xss 0.016250 0.000736

# %%
# precision curve for mitm attack
plt.figure(figsize=(8, 6))
for i in range(len(type_encoder.classes_)):
    precision_i, _, _ = precision_recall_curve(y_test_seq[:, i], y_pred_probs[:, i])
    plt.plot(range(len(precision_i)), precision_i, label=f'Class {type_encoder.classes_[i]}')
plt.title('Multi-class Precision Curve')
plt.xlabel('Threshold Index')
plt.ylabel('Precision')
plt.legend()
plt.show()


plt.figure(figsize=(8, 6))
for i in range(len(type_encoder.classes_)):
    if type_encoder.classes_[i] == 'mitm':
        precision_i, _, _ = precision_recall_curve(y_test_seq[:, i], y_pred_probs[:, i])
        plt.plot(range(len(precision_i)), precision_i, label=f'Class {type_encoder.classes_[i]}')
plt.title('MitM Attack Precision Curve')
plt.xlabel('Threshold Index')
plt.ylabel('Precision')
plt.legend()
plt.show()  

# precision curve for mitm attack
plt.figure(figsize=(8, 6))
for i in range(len(type_encoder.classes_)):
    if type_encoder.classes_[i] == 'normal':
        precision_i, _, _ = precision_recall_curve(y_test_seq[:, i], y_pred_probs[:, i])
        plt.plot(range(len(precision_i)), precision_i, label=f'Class {type_encoder.classes_[i]}')
plt.title('Normal Precision Curve')
plt.xlabel('Threshold Index')
plt.ylabel('Precision')
plt.legend()
plt.show() 

# precision curve for mitm attack
plt.figure(figsize=(8, 6))
for i in range(len(type_encoder.classes_)):
    if type_encoder.classes_[i] == 'dos':
        precision_i, _, _ = precision_recall_curve(y_test_seq[:, i], y_pred_probs[:, i])
        plt.plot(range(len(precision_i)), precision_i, label=f'Class {type_encoder.classes_[i]}')
plt.title('Dos Attack Precision Curve')
plt.xlabel('Threshold Index')
plt.ylabel('Precision')
plt.legend()
plt.show() 

# precision curve for mitm attack
plt.figure(figsize=(8, 6))
for i in range(len(type_encoder.classes_)):
    if type_encoder.classes_[i] == 'ddos':
        precision_i, _, _ = precision_recall_curve(y_test_seq[:, i], y_pred_probs[:, i])
        plt.plot(range(len(precision_i)), precision_i, label=f'Class {type_encoder.classes_[i]}')
plt.title('DDoS Attack Precision Curve')
plt.xlabel('Threshold Index')
plt.ylabel('Precision')
plt.legend()
plt.show() 

# precision curve for mitm attack
plt.figure(figsize=(8, 6))
for i in range(len(type_encoder.classes_)):
    if type_encoder.classes_[i] == 'scanning':
        precision_i, _, _ = precision_recall_curve(y_test_seq[:, i], y_pred_probs[:, i])
        plt.plot(range(len(precision_i)), precision_i, label=f'Class {type_encoder.classes_[i]}')
plt.title('Scanning Attack Precision Curve')
plt.xlabel('Threshold Index')
plt.ylabel('Precision')
plt.legend()
plt.show() 

# precision curve for mitm attack
plt.figure(figsize=(8, 6))
for i in range(len(type_encoder.classes_)):
    if type_encoder.classes_[i] == 'backdoor':
        precision_i, _, _ = precision_recall_curve(y_test_seq[:, i], y_pred_probs[:, i])
        plt.plot(range(len(precision_i)), precision_i, label=f'Class {type_encoder.classes_[i]}')
plt.title('Backdoor Attack Precision Curve')
plt.xlabel('Threshold Index')
plt.ylabel('Precision')
plt.legend()
plt.show() 

# precision curve for mitm attack
plt.figure(figsize=(8, 6))
for i in range(len(type_encoder.classes_)):
    if type_encoder.classes_[i] == 'xss':
        precision_i, _, _ = precision_recall_curve(y_test_seq[:, i], y_pred_probs[:, i])
        plt.plot(range(len(precision_i)), precision_i, label=f'Class {type_encoder.classes_[i]}')
plt.title('XSS attack Precision Curve')
plt.xlabel('Threshold Index')
plt.ylabel('Precision')
plt.legend()
plt.show() 

# precision curve for mitm attack
plt.figure(figsize=(8, 6))
for i in range(len(type_encoder.classes_)):
    if type_encoder.classes_[i] == 'injection':
        precision_i, _, _ = precision_recall_curve(y_test_seq[:, i], y_pred_probs[:, i])
        plt.plot(range(len(precision_i)), precision_i, label=f'Class {type_encoder.classes_[i]}')
plt.title('Injection Attack Precision Curve')
plt.xlabel('Threshold Index')
plt.ylabel('Precision')
plt.legend()
plt.show() 

# precision curve for mitm attack
plt.figure(figsize=(8, 6))
for i in range(len(type_encoder.classes_)):
    if type_encoder.classes_[i] == 'password':
        precision_i, _, _ = precision_recall_curve(y_test_seq[:, i], y_pred_probs[:, i])
        plt.plot(range(len(precision_i)), precision_i, label=f'Class {type_encoder.classes_[i]}')
plt.title('Password Attack Precision Curve')
plt.xlabel('Threshold Index')
plt.ylabel('Precision')
plt.legend()
plt.show()

# %%
# precision curve for mitm attack

# recall curve for multi-class
plt.figure(figsize=(8, 6))
for i in range(len(type_encoder.classes_)):
    _, recall_i, _ = precision_recall_curve(y_test_seq[:, i], y_pred_probs[:, i])
    plt.plot(range(len(recall_i)), recall_i, label=f'Class {type_encoder.classes_[i]}')
plt.title('Multi-class Recall Curve')
plt.xlabel('Threshold Index')
plt.ylabel('Recall')
plt.legend()
plt.show()

# Recall curve for mitm attack
plt.figure(figsize=(8, 6))
for i in range(len(type_encoder.classes_)):
    if type_encoder.classes_[i] == 'mitm':
        _, recall_i, _ = precision_recall_curve(y_test_seq[:, i], y_pred_probs[:, i])
        plt.plot(range(len(recall_i)), recall_i, label=f'Class {type_encoder.classes_[i]}')
plt.title('MitM Attack Recall Curve')
plt.xlabel('Threshold Index')
plt.ylabel('Recall')
plt.legend()
plt.show()  

# Recall curve for mitm attack
plt.figure(figsize=(8, 6))
for i in range(len(type_encoder.classes_)):
    if type_encoder.classes_[i] == 'normal':
        _, recall_i, _ = precision_recall_curve(y_test_seq[:, i], y_pred_probs[:, i])
        plt.plot(range(len(recall_i)), recall_i, label=f'Class {type_encoder.classes_[i]}')
plt.title('Normal Recall Curve')
plt.xlabel('Threshold Index')
plt.ylabel('Recall')
plt.legend()
plt.show() 

# Recall curve for mitm attack
plt.figure(figsize=(8, 6))
for i in range(len(type_encoder.classes_)):
    if type_encoder.classes_[i] == 'dos':
        _, recall_i, _ = precision_recall_curve(y_test_seq[:, i], y_pred_probs[:, i])
        plt.plot(range(len(recall_i)), recall_i, label=f'Class {type_encoder.classes_[i]}')
plt.title('Dos Attack Recall Curve')
plt.xlabel('Threshold Index')
plt.ylabel('Recall')
plt.legend()
plt.show() 

# precision curve for mitm attack
plt.figure(figsize=(8, 6))
for i in range(len(type_encoder.classes_)):
    if type_encoder.classes_[i] == 'ddos':
        _, recall_i, _ = precision_recall_curve(y_test_seq[:, i], y_pred_probs[:, i])
        plt.plot(range(len(recall_i)), recall_i, label=f'Class {type_encoder.classes_[i]}')
plt.title('DDoS Attack Recall Curve')
plt.xlabel('Threshold Index')
plt.ylabel('Recall')
plt.legend()
plt.show() 

# precision curve for mitm attack
plt.figure(figsize=(8, 6))
for i in range(len(type_encoder.classes_)):
    if type_encoder.classes_[i] == 'scanning':
        _, recall_i, _ = precision_recall_curve(y_test_seq[:, i], y_pred_probs[:, i])
        plt.plot(range(len(recall_i)), recall_i, label=f'Class {type_encoder.classes_[i]}')
plt.title('Scanning Attack Recall Curve')
plt.xlabel('Threshold Index')
plt.ylabel('Recall')
plt.legend()
plt.show() 

# precision curve for mitm attack
plt.figure(figsize=(8, 6))
for i in range(len(type_encoder.classes_)):
    if type_encoder.classes_[i] == 'backdoor':
        _, recall_i, _ = precision_recall_curve(y_test_seq[:, i], y_pred_probs[:, i])
        plt.plot(range(len(recall_i)), recall_i, label=f'Class {type_encoder.classes_[i]}')
plt.title('Backdoor Attack Recall Curve')
plt.xlabel('Threshold Index')
plt.ylabel('Recall')
plt.legend()
plt.show() 

# precision curve for mitm attack
plt.figure(figsize=(8, 6))
for i in range(len(type_encoder.classes_)):
    if type_encoder.classes_[i] == 'xss':
        _, recall_i, _ = precision_recall_curve(y_test_seq[:, i], y_pred_probs[:, i])
        plt.plot(range(len(recall_i)), recall_i, label=f'Class {type_encoder.classes_[i]}')
plt.title('XSS Attack Recall Curve')
plt.xlabel('Threshold Index')
plt.ylabel('Recall')
plt.legend()
plt.show() 

# precision curve for mitm attack
plt.figure(figsize=(8, 6))
for i in range(len(type_encoder.classes_)):
    if type_encoder.classes_[i] == 'injection':
        _, recall_i, _ = precision_recall_curve(y_test_seq[:, i], y_pred_probs[:, i])
        plt.plot(range(len(recall_i)), recall_i, label=f'Class {type_encoder.classes_[i]}')
plt.title('Injection Attack Recall Curve')
plt.xlabel('Threshold Index')
plt.ylabel('Recall')
plt.legend()
plt.show() 

# precision curve for mitm attack
plt.figure(figsize=(8, 6))
for i in range(len(type_encoder.classes_)):
    if type_encoder.classes_[i] == 'password':
        _, recall_i, _ = precision_recall_curve(y_test_seq[:, i], y_pred_probs[:, i])
        plt.plot(range(len(recall_i)), recall_i, label=f'Class {type_encoder.classes_[i]}')
plt.title('Password Attack Recall Curve')
plt.xlabel('Threshold Index')
plt.ylabel('Recall')
plt.legend()
plt.show()

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Bidirectional, LSTM, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from sklearn.utils.class_weight import compute_class_weight
from tensorflow.keras.metrics import Precision
from tensorflow.keras.layers import LayerNormalization
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import Recall, AUC
from sklearn.metrics import (confusion_matrix, accuracy_score, recall_score, precision_score, f1_score, matthews_corrcoef, roc_auc_score, classification_report, roc_curve, precision_recall_curve)
import matplotlib.pyplot as plt
from tensorflow.keras.optimizers.schedules import CosineDecayRestarts


# Model definition
model = Sequential([
    Bidirectional(LSTM(
        448,                       
        return_sequences=True,
        recurrent_dropout=0.1,
        recurrent_activation='sigmoid',
        activation='tanh',
        kernel_regularizer=l2(1e-5)
    ), input_shape=(X_train_seq.shape[1], X_train_seq.shape[2])),
    LayerNormalization(),
    Dropout(0.1),

    Bidirectional(LSTM(
        192,
        recurrent_dropout=0.3,
        recurrent_activation='sigmoid', 
        activation='tanh',
        kernel_regularizer=l2(1e-5)
    )),
    LayerNormalization(),
    Dropout(0.3),

    Dense(56, activation='relu', kernel_regularizer=l2(1e-5)),
    Dropout(0.3),

    Dense(32, activation='relu'),
    Dropout(0.2),

    Dense(9, activation='softmax')
])

model.summary()

lr_schedule = CosineDecayRestarts(initial_learning_rate=0.00103, first_decay_steps=5)
optimizer = Adam(learning_rate=lr_schedule, clipnorm=1.0)

# optimizer = Adam(
#     learning_rate=0.0001,  # Very low initial LR 0.0002 <> 0.0001
#     clipnorm=1.0,  # Gradient clipping to prevent exploding gradients
# )

model.compile(
    optimizer=optimizer,
    loss=focal_loss(gamma=1.0, alpha=0.2),
    metrics=[
        'accuracy', 
        AUC(name='auc'), 
        Recall(), 
        Precision(), 
        MultiClassGMeanMetric(num_classes=y_train_seq_final.shape[1])
    ])

# Early stopping
early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=3,
    mode='min',
    restore_best_weights=True,
    verbose=1
)

# frequencies = np.sum(y_train_seq_final, axis=0)
# median_freq = np.median(frequencies)
# class_weights = {cls: median_freq / count for cls, count in enumerate(frequencies)}

print("Class weights:", class_weights)

# Train
bhistory = model.fit(
    X_train_seq_final, y_train_seq_final,
    validation_data=(X_val_seq, y_val_seq),
    epochs=50,
    batch_size=128,
    shuffle=False,
    callbacks=[early_stopping],
    class_weight=class_weights,
    verbose=1
)

results = model.evaluate(X_test_seq, y_test_seq, verbose=2)

print("Test Loss: {}".format(results[0]))
print("Test Accuracy: {}".format(results[1]))
# Out:
# /home/jinesh-subedi/htdocs/thesis/thesisStudy/lib/python3.12/site-packages/keras/src/layers/rnn/bidirectional.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ bidirectional_2 (Bidirectional) │ (None, 10, 896)        │     1,766,912 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ layer_normalization_2           │ (None, 10, 896)        │         1,792 │
# │ (LayerNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 10, 896)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_3 (Bidirectional) │ (None, 384)            │     1,672,704 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ layer_normalization_3           │ (None, 384)            │           768 │
# │ (LayerNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 384)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 56)             │        21,560 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 56)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 32)             │         1,824 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 9)              │           297 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,465,857 (13.22 MB)
#  Trainable params: 3,465,857 (13.22 MB)
#  Non-trainable params: 0 (0.00 B)
# Class weights: {np.int64(5): 0.17038307504990158, np.int64(8): 2.556572451675706, np.int64(2): 2.5422543732282374, np.int64(0): 2.548995649837952, np.int64(1): 2.5434414180717684, np.int64(3): 2.550388000173408, np.int64(4): 2.590616853378426, np.int64(6): 2.5615818028232793, np.int64(7): 2.5483993935455924}
# Epoch 1/50
# 2299/2299 ━━━━━━━━━━━━━━━━━━━━ 177s 74ms/step - accuracy: 0.7161 - auc: 0.9538 - loss: 0.1515 - multi_class_gmean: 0.5608 - precision_1: 0.8711 - recall_1: 0.5852 - val_accuracy: 0.8689 - val_auc: 0.9912 - val_loss: 0.0669 - val_multi_class_gmean: 0.8681 - val_precision_1: 0.9457 - val_recall_1: 0.7858
# Epoch 2/50
# 2299/2299 ━━━━━━━━━━━━━━━━━━━━ 169s 73ms/step - accuracy: 0.8516 - auc: 0.9884 - loss: 0.0728 - multi_class_gmean: 0.8247 - precision_1: 0.9131 - recall_1: 0.7853 - val_accuracy: 0.9295 - val_auc: 0.9964 - val_loss: 0.0404 - val_multi_class_gmean: 0.9332 - val_precision_1: 0.9520 - val_recall_1: 0.9191
# Epoch 3/50
# 2299/2299 ━━━━━━━━━━━━━━━━━━━━ 169s 73ms/step - accuracy: 0.9007 - auc: 0.9938 - loss: 0.0503 - multi_class_gmean: 0.8882 - precision_1: 0.9336 - recall_1: 0.8601 - val_accuracy: 0.9383 - val_auc: 0.9976 - val_loss: 0.0306 - val_multi_class_gmean: 0.9313 - val_precision_1: 0.9541 - val_recall_1: 0.9308
# Epoch 4/50
# 2299/2299 ━━━━━━━━━━━━━━━━━━━━ 171s 74ms/step - accuracy: 0.9214 - auc: 0.9958 - loss: 0.0390 - multi_class_gmean: 0.9140 - precision_1: 0.9451 - recall_1: 0.8927 - val_accuracy: 0.9622 - val_auc: 0.9985 - val_loss: 0.0239 - val_multi_class_gmean: 0.9666 - val_precision_1: 0.9707 - val_recall_1: 0.9507
# Epoch 5/50
# 2299/2299 ━━━━━━━━━━━━━━━━━━━━ 173s 75ms/step - accuracy: 0.9328 - auc: 0.9969 - loss: 0.0327 - multi_class_gmean: 0.9283 - precision_1: 0.9509 - recall_1: 0.9102 - val_accuracy: 0.9657 - val_auc: 0.9988 - val_loss: 0.0204 - val_multi_class_gmean: 0.9723 - val_precision_1: 0.9734 - val_recall_1: 0.9588
# Epoch 6/50
# 2299/2299 ━━━━━━━━━━━━━━━━━━━━ 173s 75ms/step - accuracy: 0.9416 - auc: 0.9976 - loss: 0.0284 - multi_class_gmean: 0.9396 - precision_1: 0.9563 - recall_1: 0.9232 - val_accuracy: 0.9714 - val_auc: 0.9990 - val_loss: 0.0178 - val_multi_class_gmean: 0.9795 - val_precision_1: 0.9765 - val_recall_1: 0.9651
# Epoch 7/50
# 2299/2299 ━━━━━━━━━━━━━━━━━━━━ 173s 75ms/step - accuracy: 0.9477 - auc: 0.9980 - loss: 0.0253 - multi_class_gmean: 0.9472 - precision_1: 0.9601 - recall_1: 0.9329 - val_accuracy: 0.9735 - val_auc: 0.9991 - val_loss: 0.0162 - val_multi_class_gmean: 0.9817 - val_precision_1: 0.9786 - val_recall_1: 0.9679
# Epoch 8/50
# 2299/2299 ━━━━━━━━━━━━━━━━━━━━ 173s 75ms/step - accuracy: 0.9525 - auc: 0.9982 - loss: 0.0231 - multi_class_gmean: 0.9529 - precision_1: 0.9633 - recall_1: 0.9392 - val_accuracy: 0.9762 - val_auc: 0.9993 - val_loss: 0.0147 - val_multi_class_gmean: 0.9852 - val_precision_1: 0.9804 - val_recall_1: 0.9723
# Epoch 9/50
# 2299/2299 ━━━━━━━━━━━━━━━━━━━━ 174s 75ms/step - accuracy: 0.9568 - auc: 0.9985 - loss: 0.0211 - multi_class_gmean: 0.9584 - precision_1: 0.9660 - recall_1: 0.9457 - val_accuracy: 0.9786 - val_auc: 0.9994 - val_loss: 0.0135 - val_multi_class_gmean: 0.9855 - val_precision_1: 0.9823 - val_recall_1: 0.9749
# Epoch 10/50
# 2299/2299 ━━━━━━━━━━━━━━━━━━━━ 174s 76ms/step - accuracy: 0.9596 - auc: 0.9986 - loss: 0.0197 - multi_class_gmean: 0.9619 - precision_1: 0.9679 - recall_1: 0.9500 - val_accuracy: 0.9760 - val_auc: 0.9994 - val_loss: 0.0132 - val_multi_class_gmean: 0.9833 - val_precision_1: 0.9805 - val_recall_1: 0.9720
# Epoch 11/50
# 2299/2299 ━━━━━━━━━━━━━━━━━━━━ 174s 76ms/step - accuracy: 0.9622 - auc: 0.9988 - loss: 0.0184 - multi_class_gmean: 0.9650 - precision_1: 0.9696 - recall_1: 0.9534 - val_accuracy: 0.9811 - val_auc: 0.9995 - val_loss: 0.0118 - val_multi_class_gmean: 0.9893 - val_precision_1: 0.9838 - val_recall_1: 0.9776
# Epoch 12/50
# 2299/2299 ━━━━━━━━━━━━━━━━━━━━ 175s 76ms/step - accuracy: 0.9650 - auc: 0.9989 - loss: 0.0174 - multi_class_gmean: 0.9680 - precision_1: 0.9718 - recall_1: 0.9571 - val_accuracy: 0.9729 - val_auc: 0.9994 - val_loss: 0.0131 - val_multi_class_gmean: 0.9759 - val_precision_1: 0.9764 - val_recall_1: 0.9699
# Epoch 13/50
# 2299/2299 ━━━━━━━━━━━━━━━━━━━━ 175s 76ms/step - accuracy: 0.9661 - auc: 0.9990 - loss: 0.0167 - multi_class_gmean: 0.9691 - precision_1: 0.9721 - recall_1: 0.9590 - val_accuracy: 0.9797 - val_auc: 0.9995 - val_loss: 0.0115 - val_multi_class_gmean: 0.9862 - val_precision_1: 0.9823 - val_recall_1: 0.9759
# Epoch 14/50
# 2299/2299 ━━━━━━━━━━━━━━━━━━━━ 175s 76ms/step - accuracy: 0.9677 - auc: 0.9990 - loss: 0.0160 - multi_class_gmean: 0.9707 - precision_1: 0.9738 - recall_1: 0.9613 - val_accuracy: 0.9801 - val_auc: 0.9996 - val_loss: 0.0109 - val_multi_class_gmean: 0.9858 - val_precision_1: 0.9827 - val_recall_1: 0.9783
# Epoch 15/50
# 2299/2299 ━━━━━━━━━━━━━━━━━━━━ 176s 77ms/step - accuracy: 0.9696 - auc: 0.9991 - loss: 0.0153 - multi_class_gmean: 0.9728 - precision_1: 0.9748 - recall_1: 0.9635 - val_accuracy: 0.9826 - val_auc: 0.9996 - val_loss: 0.0101 - val_multi_class_gmean: 0.9887 - val_precision_1: 0.9849 - val_recall_1: 0.9801
# Epoch 16/50
# 2299/2299 ━━━━━━━━━━━━━━━━━━━━ 177s 77ms/step - accuracy: 0.9707 - auc: 0.9991 - loss: 0.0149 - multi_class_gmean: 0.9739 - precision_1: 0.9756 - recall_1: 0.9646 - val_accuracy: 0.9847 - val_auc: 0.9997 - val_loss: 0.0097 - val_multi_class_gmean: 0.9925 - val_precision_1: 0.9865 - val_recall_1: 0.9823
# Epoch 17/50
# 2299/2299 ━━━━━━━━━━━━━━━━━━━━ 177s 77ms/step - accuracy: 0.9713 - auc: 0.9992 - loss: 0.0144 - multi_class_gmean: 0.9743 - precision_1: 0.9764 - recall_1: 0.9659 - val_accuracy: 0.9820 - val_auc: 0.9996 - val_loss: 0.0099 - val_multi_class_gmean: 0.9854 - val_precision_1: 0.9840 - val_recall_1: 0.9801
# Epoch 18/50
# 2299/2299 ━━━━━━━━━━━━━━━━━━━━ 177s 77ms/step - accuracy: 0.9733 - auc: 0.9992 - loss: 0.0137 - multi_class_gmean: 0.9762 - precision_1: 0.9778 - recall_1: 0.9682 - val_accuracy: 0.9859 - val_auc: 0.9997 - val_loss: 0.0091 - val_multi_class_gmean: 0.9924 - val_precision_1: 0.9877 - val_recall_1: 0.9831
# Epoch 19/50
# 2299/2299 ━━━━━━━━━━━━━━━━━━━━ 178s 77ms/step - accuracy: 0.9737 - auc: 0.9993 - loss: 0.0133 - multi_class_gmean: 0.9768 - precision_1: 0.9780 - recall_1: 0.9690 - val_accuracy: 0.9867 - val_auc: 0.9996 - val_loss: 0.0090 - val_multi_class_gmean: 0.9930 - val_precision_1: 0.9886 - val_recall_1: 0.9848
# Epoch 20/50
# 2299/2299 ━━━━━━━━━━━━━━━━━━━━ 178s 77ms/step - accuracy: 0.9749 - auc: 0.9993 - loss: 0.0129 - multi_class_gmean: 0.9781 - precision_1: 0.9789 - recall_1: 0.9705 - val_accuracy: 0.9883 - val_auc: 0.9997 - val_loss: 0.0084 - val_multi_class_gmean: 0.9933 - val_precision_1: 0.9898 - val_recall_1: 0.9859
# Epoch 21/50
# 2299/2299 ━━━━━━━━━━━━━━━━━━━━ 193s 84ms/step - accuracy: 0.9753 - auc: 0.9993 - loss: 0.0127 - multi_class_gmean: 0.9782 - precision_1: 0.9792 - recall_1: 0.9710 - val_accuracy: 0.9876 - val_auc: 0.9997 - val_loss: 0.0084 - val_multi_class_gmean: 0.9924 - val_precision_1: 0.9891 - val_recall_1: 0.9849
# Epoch 22/50
# 2299/2299 ━━━━━━━━━━━━━━━━━━━━ 204s 89ms/step - accuracy: 0.9754 - auc: 0.9993 - loss: 0.0126 - multi_class_gmean: 0.9783 - precision_1: 0.9791 - recall_1: 0.9712 - val_accuracy: 0.9854 - val_auc: 0.9998 - val_loss: 0.0084 - val_multi_class_gmean: 0.9901 - val_precision_1: 0.9875 - val_recall_1: 0.9843
# Epoch 23/50
# 2299/2299 ━━━━━━━━━━━━━━━━━━━━ 206s 90ms/step - accuracy: 0.9766 - auc: 0.9994 - loss: 0.0121 - multi_class_gmean: 0.9796 - precision_1: 0.9800 - recall_1: 0.9727 - val_accuracy: 0.9878 - val_auc: 0.9997 - val_loss: 0.0084 - val_multi_class_gmean: 0.9931 - val_precision_1: 0.9892 - val_recall_1: 0.9856
# Epoch 24/50
# 2299/2299 ━━━━━━━━━━━━━━━━━━━━ 207s 90ms/step - accuracy: 0.9769 - auc: 0.9993 - loss: 0.0121 - multi_class_gmean: 0.9796 - precision_1: 0.9801 - recall_1: 0.9729 - val_accuracy: 0.9871 - val_auc: 0.9998 - val_loss: 0.0082 - val_multi_class_gmean: 0.9920 - val_precision_1: 0.9892 - val_recall_1: 0.9848
# Epoch 25/50
# 2299/2299 ━━━━━━━━━━━━━━━━━━━━ 209s 91ms/step - accuracy: 0.9773 - auc: 0.9994 - loss: 0.0117 - multi_class_gmean: 0.9802 - precision_1: 0.9807 - recall_1: 0.9738 - val_accuracy: 0.9860 - val_auc: 0.9997 - val_loss: 0.0082 - val_multi_class_gmean: 0.9905 - val_precision_1: 0.9870 - val_recall_1: 0.9840
# Epoch 26/50
# 2299/2299 ━━━━━━━━━━━━━━━━━━━━ 210s 91ms/step - accuracy: 0.9782 - auc: 0.9994 - loss: 0.0114 - multi_class_gmean: 0.9811 - precision_1: 0.9811 - recall_1: 0.9746 - val_accuracy: 0.9890 - val_auc: 0.9998 - val_loss: 0.0075 - val_multi_class_gmean: 0.9927 - val_precision_1: 0.9901 - val_recall_1: 0.9869
# Epoch 27/50
# 2299/2299 ━━━━━━━━━━━━━━━━━━━━ 212s 92ms/step - accuracy: 0.9785 - auc: 0.9994 - loss: 0.0113 - multi_class_gmean: 0.9814 - precision_1: 0.9812 - recall_1: 0.9751 - val_accuracy: 0.9867 - val_auc: 0.9998 - val_loss: 0.0080 - val_multi_class_gmean: 0.9900 - val_precision_1: 0.9879 - val_recall_1: 0.9845
# Epoch 28/50
# 2299/2299 ━━━━━━━━━━━━━━━━━━━━ 213s 93ms/step - accuracy: 0.9782 - auc: 0.9995 - loss: 0.0111 - multi_class_gmean: 0.9811 - precision_1: 0.9813 - recall_1: 0.9750 - val_accuracy: 0.9876 - val_auc: 0.9997 - val_loss: 0.0077 - val_multi_class_gmean: 0.9912 - val_precision_1: 0.9891 - val_recall_1: 0.9859
# Epoch 29/50
# 2299/2299 ━━━━━━━━━━━━━━━━━━━━ 215s 93ms/step - accuracy: 0.9790 - auc: 0.9994 - loss: 0.0110 - multi_class_gmean: 0.9817 - precision_1: 0.9818 - recall_1: 0.9759 - val_accuracy: 0.9875 - val_auc: 0.9997 - val_loss: 0.0081 - val_multi_class_gmean: 0.9926 - val_precision_1: 0.9887 - val_recall_1: 0.9858
# Epoch 29: early stopping
# Restoring model weights from the end of the best epoch: 26.
# 2757/2757 - 38s - 14ms/step - accuracy: 0.9884 - auc: 0.9998 - loss: 0.0075 - multi_class_gmean: 0.9915 - precision_1: 0.9897 - recall_1: 0.9861
# Test Loss: 0.007471328601241112
# Test Accuracy: 0.9883787035942078

# %%
import seaborn as sns

# original class labels (what was in df[TARGET_TYPE])
print(type_encoder.classes_)

# numeric codes assigned
for i, cls in enumerate(type_encoder.classes_):
    print(f"Encoded class {i} -> {cls}")


# Print classification report
y_pred_probs = model.predict(X_test_seq)
y_pred_classes = y_pred_probs.argmax(axis=1)
y_true_classes = y_test_seq.argmax(axis=1)
print(classification_report(y_true_classes, y_pred_classes))

#confusion matrix
cm = confusion_matrix(y_true_classes, y_pred_classes)

# For multi-class, FNR and FPR are not simply tn, fp, fn, tp.
# If you want per-class FNR/FPR:
fnr = []
fpr = []
for i in range(cm.shape[0]):
    fn = cm[i, :].sum() - cm[i, i]
    tp = cm[i, i]
    fp = cm[:, i].sum() - cm[i, i]
    tn = cm.sum() - (tp + fn + fp)
    fnr.append(fn / (fn + tp) if (fn + tp) > 0 else 0)
    fpr.append(fp / (fp + tn) if (fp + tn) > 0 else 0)

results_df = pd.DataFrame({
    "Class": type_encoder.classes_,
    "FNR": fnr,
    "FPR": fpr
})
print(results_df.to_string(index=False))


# Plot confusion matrix
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=type_encoder.classes_,
            yticklabels=type_encoder.classes_)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()


# plot validation loss and accuracy
plt.figure(figsize=(12, 6))
plt.plot(bhistory.history['loss'], label='Train Loss')
plt.plot(bhistory.history['val_loss'], label='Validation Loss')
plt.plot(bhistory.history['accuracy'], label='Train Accuracy')
plt.plot(bhistory.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Loss and Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Loss/Accuracy')
plt.legend()
plt.show()

# sensitivity vs 1-specificity plot for multi-class
plt.figure(figsize=(8, 6))
for i in range(len(type_encoder.classes_)):
    fpr_i, tpr_i, _ = roc_curve(y_test_seq[:, i], y_pred_probs[:, i])
    plt.plot(fpr_i, tpr_i, label=f'Class {type_encoder.classes_[i]} (AUC = {roc_auc_score(y_test_seq[:, i], y_pred_probs[:, i]):.2f})')
plt.plot([0, 1], [0, 1], 'k--')  # Diagonal line
plt.title('Multi-class ROC Curve')
plt.xlabel('1 - Specificity (FPR)')
plt.ylabel('Sensitivity (TPR)')
plt.legend()
plt.show()  

# precision-recall curve for multi-class
plt.figure(figsize=(8, 6))
for i in range(len(type_encoder.classes_)):
    precision_i, recall_i, _ = precision_recall_curve(y_test_seq[:, i], y_pred_probs[:, i])
    plt.plot(recall_i, precision_i, label=f'Class {type_encoder.classes_[i]}')
plt.title('Multi-class Precision-Recall Curve')
plt.xlabel('Recall')
plt.ylabel('Precision') 
plt.legend()
plt.show()

# gmean history
plt.figure(figsize=(12, 6))
plt.plot(bhistory.history['multi_class_gmean'], label='Train G-Mean')
plt.plot(bhistory.history['val_multi_class_gmean'], label='Validation G-Mean')
plt.title('Final Model Training and Validation G-Mean')
plt.xlabel('Epoch')
plt.ylabel('G-Mean')
plt.legend()
plt.show()
# Out:
# ['backdoor' 'ddos' 'dos' 'injection' 'mitm' 'normal' 'password' 'scanning'
#  'xss']
# Encoded class 0 -> backdoor
# Encoded class 1 -> ddos
# Encoded class 2 -> dos
# Encoded class 3 -> injection
# Encoded class 4 -> mitm
# Encoded class 5 -> normal
# Encoded class 6 -> password
# Encoded class 7 -> scanning
# Encoded class 8 -> xss
# 2757/2757 ━━━━━━━━━━━━━━━━━━━━ 34s 12ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      3999
#            1       0.98      1.00      0.99      3999
#            2       0.99      0.94      0.97      4000
#            3       0.98      0.99      0.98      3999
#            4       0.42      0.98      0.59       209
#            5       0.99      0.99      0.99     59995
#            6       0.98      0.99      0.99      3999
#            7       0.98      1.00      0.99      4000
#            8       0.98      0.99      0.99      4000
#
#     accuracy                           0.99     88200
#    macro avg       0.92      0.99      0.94     88200
# weighted avg       0.99      0.99      0.99     88200
#
#     Class      FNR      FPR
#  backdoor 0.000000 0.000119
#      ddos 0.003501 0.000950
#       dos 0.058000 0.000344
# injection 0.013753 0.001057
#      mitm 0.023923 0.003171
#    normal 0.010451 0.010814
#  password 0.010503 0.000914
#  scanning 0.003500 0.000926
#       xss 0.009000 0.000926

# %%
# precision curve for mitm attack
plt.figure(figsize=(8, 6))
for i in range(len(type_encoder.classes_)):
    precision_i, _, _ = precision_recall_curve(y_test_seq[:, i], y_pred_probs[:, i])
    plt.plot(range(len(precision_i)), precision_i, label=f'Class {type_encoder.classes_[i]}')
plt.title('Multi-class Precision Curve')
plt.xlabel('Threshold Index')
plt.ylabel('Precision')
plt.legend()
plt.show()


plt.figure(figsize=(8, 6))
for i in range(len(type_encoder.classes_)):
    if type_encoder.classes_[i] == 'mitm':
        precision_i, _, _ = precision_recall_curve(y_test_seq[:, i], y_pred_probs[:, i])
        plt.plot(range(len(precision_i)), precision_i, label=f'Class {type_encoder.classes_[i]}')
plt.title('MitM Attack Precision Curve')
plt.xlabel('Threshold Index')
plt.ylabel('Precision')
plt.legend()
plt.show()  

# precision curve for mitm attack
plt.figure(figsize=(8, 6))
for i in range(len(type_encoder.classes_)):
    if type_encoder.classes_[i] == 'normal':
        precision_i, _, _ = precision_recall_curve(y_test_seq[:, i], y_pred_probs[:, i])
        plt.plot(range(len(precision_i)), precision_i, label=f'Class {type_encoder.classes_[i]}')
plt.title('Normal Precision Curve')
plt.xlabel('Threshold Index')
plt.ylabel('Precision')
plt.legend()
plt.show() 

# precision curve for mitm attack
plt.figure(figsize=(8, 6))
for i in range(len(type_encoder.classes_)):
    if type_encoder.classes_[i] == 'dos':
        precision_i, _, _ = precision_recall_curve(y_test_seq[:, i], y_pred_probs[:, i])
        plt.plot(range(len(precision_i)), precision_i, label=f'Class {type_encoder.classes_[i]}')
plt.title('Dos Attack Precision Curve')
plt.xlabel('Threshold Index')
plt.ylabel('Precision')
plt.legend()
plt.show() 

# precision curve for mitm attack
plt.figure(figsize=(8, 6))
for i in range(len(type_encoder.classes_)):
    if type_encoder.classes_[i] == 'ddos':
        precision_i, _, _ = precision_recall_curve(y_test_seq[:, i], y_pred_probs[:, i])
        plt.plot(range(len(precision_i)), precision_i, label=f'Class {type_encoder.classes_[i]}')
plt.title('DDoS Attack Precision Curve')
plt.xlabel('Threshold Index')
plt.ylabel('Precision')
plt.legend()
plt.show() 

# precision curve for mitm attack
plt.figure(figsize=(8, 6))
for i in range(len(type_encoder.classes_)):
    if type_encoder.classes_[i] == 'scanning':
        precision_i, _, _ = precision_recall_curve(y_test_seq[:, i], y_pred_probs[:, i])
        plt.plot(range(len(precision_i)), precision_i, label=f'Class {type_encoder.classes_[i]}')
plt.title('Scanning Attack Precision Curve')
plt.xlabel('Threshold Index')
plt.ylabel('Precision')
plt.legend()
plt.show() 

# precision curve for mitm attack
plt.figure(figsize=(8, 6))
for i in range(len(type_encoder.classes_)):
    if type_encoder.classes_[i] == 'backdoor':
        precision_i, _, _ = precision_recall_curve(y_test_seq[:, i], y_pred_probs[:, i])
        plt.plot(range(len(precision_i)), precision_i, label=f'Class {type_encoder.classes_[i]}')
plt.title('Backdoor Attack Precision Curve')
plt.xlabel('Threshold Index')
plt.ylabel('Precision')
plt.legend()
plt.show() 

# precision curve for mitm attack
plt.figure(figsize=(8, 6))
for i in range(len(type_encoder.classes_)):
    if type_encoder.classes_[i] == 'xss':
        precision_i, _, _ = precision_recall_curve(y_test_seq[:, i], y_pred_probs[:, i])
        plt.plot(range(len(precision_i)), precision_i, label=f'Class {type_encoder.classes_[i]}')
plt.title('XSS attack Precision Curve')
plt.xlabel('Threshold Index')
plt.ylabel('Precision')
plt.legend()
plt.show() 

# precision curve for mitm attack
plt.figure(figsize=(8, 6))
for i in range(len(type_encoder.classes_)):
    if type_encoder.classes_[i] == 'injection':
        precision_i, _, _ = precision_recall_curve(y_test_seq[:, i], y_pred_probs[:, i])
        plt.plot(range(len(precision_i)), precision_i, label=f'Class {type_encoder.classes_[i]}')
plt.title('Injection Attack Precision Curve')
plt.xlabel('Threshold Index')
plt.ylabel('Precision')
plt.legend()
plt.show() 

# precision curve for mitm attack
plt.figure(figsize=(8, 6))
for i in range(len(type_encoder.classes_)):
    if type_encoder.classes_[i] == 'password':
        precision_i, _, _ = precision_recall_curve(y_test_seq[:, i], y_pred_probs[:, i])
        plt.plot(range(len(precision_i)), precision_i, label=f'Class {type_encoder.classes_[i]}')
plt.title('Password Attack Precision Curve')
plt.xlabel('Threshold Index')
plt.ylabel('Precision')
plt.legend()
plt.show()

# %%
# precision curve for mitm attack

# recall curve for multi-class
plt.figure(figsize=(8, 6))
for i in range(len(type_encoder.classes_)):
    _, recall_i, _ = precision_recall_curve(y_test_seq[:, i], y_pred_probs[:, i])
    plt.plot(range(len(recall_i)), recall_i, label=f'Class {type_encoder.classes_[i]}')
plt.title('Multi-class Recall Curve')
plt.xlabel('Threshold Index')
plt.ylabel('Recall')
plt.legend()
plt.show()

# Recall curve for mitm attack
plt.figure(figsize=(8, 6))
for i in range(len(type_encoder.classes_)):
    if type_encoder.classes_[i] == 'mitm':
        _, recall_i, _ = precision_recall_curve(y_test_seq[:, i], y_pred_probs[:, i])
        plt.plot(range(len(recall_i)), recall_i, label=f'Class {type_encoder.classes_[i]}')
plt.title('MitM Attack Recall Curve')
plt.xlabel('Threshold Index')
plt.ylabel('Recall')
plt.legend()
plt.show()  

# Recall curve for mitm attack
plt.figure(figsize=(8, 6))
for i in range(len(type_encoder.classes_)):
    if type_encoder.classes_[i] == 'normal':
        _, recall_i, _ = precision_recall_curve(y_test_seq[:, i], y_pred_probs[:, i])
        plt.plot(range(len(recall_i)), recall_i, label=f'Class {type_encoder.classes_[i]}')
plt.title('Normal Recall Curve')
plt.xlabel('Threshold Index')
plt.ylabel('Recall')
plt.legend()
plt.show() 

# Recall curve for mitm attack
plt.figure(figsize=(8, 6))
for i in range(len(type_encoder.classes_)):
    if type_encoder.classes_[i] == 'dos':
        _, recall_i, _ = precision_recall_curve(y_test_seq[:, i], y_pred_probs[:, i])
        plt.plot(range(len(recall_i)), recall_i, label=f'Class {type_encoder.classes_[i]}')
plt.title('Dos Attack Recall Curve')
plt.xlabel('Threshold Index')
plt.ylabel('Recall')
plt.legend()
plt.show() 

# precision curve for mitm attack
plt.figure(figsize=(8, 6))
for i in range(len(type_encoder.classes_)):
    if type_encoder.classes_[i] == 'ddos':
        _, recall_i, _ = precision_recall_curve(y_test_seq[:, i], y_pred_probs[:, i])
        plt.plot(range(len(recall_i)), recall_i, label=f'Class {type_encoder.classes_[i]}')
plt.title('DDoS Attack Recall Curve')
plt.xlabel('Threshold Index')
plt.ylabel('Recall')
plt.legend()
plt.show() 

# precision curve for mitm attack
plt.figure(figsize=(8, 6))
for i in range(len(type_encoder.classes_)):
    if type_encoder.classes_[i] == 'scanning':
        _, recall_i, _ = precision_recall_curve(y_test_seq[:, i], y_pred_probs[:, i])
        plt.plot(range(len(recall_i)), recall_i, label=f'Class {type_encoder.classes_[i]}')
plt.title('Scanning Attack Recall Curve')
plt.xlabel('Threshold Index')
plt.ylabel('Recall')
plt.legend()
plt.show() 

# precision curve for mitm attack
plt.figure(figsize=(8, 6))
for i in range(len(type_encoder.classes_)):
    if type_encoder.classes_[i] == 'backdoor':
        _, recall_i, _ = precision_recall_curve(y_test_seq[:, i], y_pred_probs[:, i])
        plt.plot(range(len(recall_i)), recall_i, label=f'Class {type_encoder.classes_[i]}')
plt.title('Backdoor Attack Recall Curve')
plt.xlabel('Threshold Index')
plt.ylabel('Recall')
plt.legend()
plt.show() 

# precision curve for mitm attack
plt.figure(figsize=(8, 6))
for i in range(len(type_encoder.classes_)):
    if type_encoder.classes_[i] == 'xss':
        _, recall_i, _ = precision_recall_curve(y_test_seq[:, i], y_pred_probs[:, i])
        plt.plot(range(len(recall_i)), recall_i, label=f'Class {type_encoder.classes_[i]}')
plt.title('XSS Attack Recall Curve')
plt.xlabel('Threshold Index')
plt.ylabel('Recall')
plt.legend()
plt.show() 

# precision curve for mitm attack
plt.figure(figsize=(8, 6))
for i in range(len(type_encoder.classes_)):
    if type_encoder.classes_[i] == 'injection':
        _, recall_i, _ = precision_recall_curve(y_test_seq[:, i], y_pred_probs[:, i])
        plt.plot(range(len(recall_i)), recall_i, label=f'Class {type_encoder.classes_[i]}')
plt.title('Injection Attack Recall Curve')
plt.xlabel('Threshold Index')
plt.ylabel('Recall')
plt.legend()
plt.show() 

# precision curve for mitm attack
plt.figure(figsize=(8, 6))
for i in range(len(type_encoder.classes_)):
    if type_encoder.classes_[i] == 'password':
        _, recall_i, _ = precision_recall_curve(y_test_seq[:, i], y_pred_probs[:, i])
        plt.plot(range(len(recall_i)), recall_i, label=f'Class {type_encoder.classes_[i]}')
plt.title('Password Attack Recall Curve')
plt.xlabel('Threshold Index')
plt.ylabel('Recall')
plt.legend()
plt.show()

# %%
#threshold optimization for multi class classification

optimal_thresholds = {}
for i in range(len(type_encoder.classes_)):
    precision_i, recall_i, thresholds_i = precision_recall_curve(y_test_seq[:, i], y_pred_probs[:, i])
    f1_scores = 2 * (precision_i * recall_i) / (precision_i + recall_i + 1e-8)
    optimal_idx = np.argmax(f1_scores)
    optimal_threshold = thresholds_i[optimal_idx] if optimal_idx < len(thresholds_i) else 1.0
    optimal_thresholds[type_encoder.classes_[i]] = optimal_threshold
print("Optimal Thresholds for each class:")
for cls, thresh in optimal_thresholds.items():
    print(f"Class {cls}: Optimal Threshold = {thresh:.4f}")

# Applying optimal thresholds to predictions
y_pred_optimal = np.zeros_like(y_pred_probs)
for i in range(len(type_encoder.classes_)):
    class_name = type_encoder.classes_[i]
    threshold = optimal_thresholds[class_name]
    y_pred_optimal[:, i] = (y_pred_probs[:, i] >= threshold).astype(int)

# Convert one-hot encoded true labels back to class indices
y_true_classes = y_test_seq.argmax(axis=1)
y_pred_classes_optimal = y_pred_optimal.argmax(axis=1)

# Print classification report with optimal thresholds
print("Classification Report with Optimal Thresholds:")
print(classification_report(y_true_classes, y_pred_classes_optimal))

#confusion matrix with optimal thresholds
cm_optimal = confusion_matrix(y_true_classes, y_pred_classes_optimal)
# For multi-class, FNR and FPR are not simply tn, fp, fn, tp.
# If you want per-class FNR/FPR:
fnr_optimal = []
fpr_optimal = []
for i in range(cm_optimal.shape[0]):
    fn = cm_optimal[i, :].sum() - cm_optimal[i, i]
    tp = cm_optimal[i, i]
    fp = cm_optimal[:, i].sum() - cm_optimal[i, i]
    tn = cm_optimal.sum() - (tp + fn + fp)
    fnr_optimal.append(fn / (fn + tp) if (fn + tp) > 0 else 0)
    fpr_optimal.append(fp / (fp + tn) if (fp + tn) > 0 else 0)

results_df_optimal = pd.DataFrame({
    "Class": type_encoder.classes_,
    "FNR": fnr_optimal,
    "FPR": fpr_optimal
})
print("Results with Optimal Thresholds:")
print(results_df_optimal.to_string(index=False))
# Out:
# Optimal Thresholds for each class:
# Class backdoor: Optimal Threshold = 0.7876
# Class ddos: Optimal Threshold = 0.7454
# Class dos: Optimal Threshold = 0.3916
# Class injection: Optimal Threshold = 0.4279
# Class mitm: Optimal Threshold = 0.7660
# Class normal: Optimal Threshold = 0.3505
# Class password: Optimal Threshold = 0.4491
# Class scanning: Optimal Threshold = 0.5381
# Class xss: Optimal Threshold = 0.5726
# Classification Report with Optimal Thresholds:
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97      3999
#            1       0.99      0.99      0.99      3999
#            2       0.98      0.96      0.97      4000
#            3       0.98      0.98      0.98      3999
#            4       0.52      0.84      0.64       209
#            5       1.00      0.99      0.99     59995
#            6       0.98      0.99      0.99      3999
#            7       0.98      0.99      0.99      4000
#            8       0.99      0.98      0.99      4000
#
#     accuracy                           0.99     88200
#    macro avg       0.93      0.97      0.95     88200
# weighted avg       0.99      0.99      0.99     88200
#
# Results with Optimal Thresholds:
#     Class      FNR      FPR
#  backdoor 0.000000 0.002696
#      ddos 0.008252 0.000463
#       dos 0.039250 0.000748
# injection 0.017754 0.000808
#      mitm 0.162679 0.001841
#    normal 0.009734 0.008899
#  password 0.006752 0.000855
#  scanning 0.006000 0.000831
#       xss 0.016500 0.000523
